# %%
# !pip install opencv-python matplotlib lxml
# !wget https://zenodo.org/api/records/5106795/files-archive
# !unzip -o files-archive
# !unzip -o validation_set
# !unzip -o train_set
# !unzip -o test_set
# !rm /kaggle/working/*.zip
# !rm /kaggle/working/files-archive
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# --2026-03-12 06:49:37--  https://zenodo.org/api/records/5106795/files-archive
# Resolving zenodo.org (zenodo.org)... 188.184.98.114, 137.138.52.235, 188.185.48.75, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘files-archive’
#
# files-archive           [           <=>      ]   5.63G  20.6MB/s    in 4m 7s
#
# 2026-03-12 06:53:45 (23.3 MB/s) - ‘files-archive’ saved [6043324001]
#
# Archive:  files-archive
#  extracting: validation_set.zip
#  extracting: test_set.zip
#  extracting: train_set.zip
# Archive:  validation_set.zip
#   inflating: validation_set/IMG_1822_01.JPG
#   inflating: validation_set/IMG_1822_01.xml
#   inflating: validation_set/IMG_1822_02.JPG
#   inflating: validation_set/IMG_1822_02.xml
#   inflating: validation_set/IMG_1822_04.JPG
#   inflating: validation_set/IMG_1822_04.xml
#   inflating: validation_set/IMG_1822_14.JPG
#   inflating: validation_set/IMG_1822_14.xml
#   inflating: validation_set/IMG_1822_15.JPG
#   inflating: validation_set/IMG_1822_15.xml
#   inflating: validation_set/IMG_1822_18.JPG
#   inflating: validation_set/IMG_1822_18.xml
#   inflating: validation_set/IMG_1822_25.JPG
#   inflating: validation_set/IMG_1822_25.xml
#   inflating: validation_set/IMG_1822_27.JPG
#   inflating: validation_set/IMG_1822_27.xml
#   inflating: validation_set/IMG_1822_32.JPG
#   inflating: validation_set/IMG_1822_32.xml
#   inflating: validation_set/IMG_1822_33.JPG
#   inflating: validation_set/IMG_1822_33.xml
#   inflating: validation_set/IMG_1822_34.JPG
#   inflating: validation_set/IMG_1822_34.xml
#   inflating: validation_set/IMG_1822_39.JPG
#   inflating: validation_set/IMG_1822_39.xml
#   inflating: validation_set/IMG_1823_01.JPG
#   inflating: validation_set/IMG_1823_01.xml
#   inflating: validation_set/IMG_1823_05.JPG
#   inflating: validation_set/IMG_1823_05.xml
#   inflating: validation_set/IMG_1823_06.JPG
#   inflating: validation_set/IMG_1823_06.xml
#   inflating: validation_set/IMG_1823_07.JPG
#   inflating: validation_set/IMG_1823_07.xml
#   inflating: validation_set/IMG_1823_09.JPG
#   inflating: validation_set/IMG_1823_09.xml
#   inflating: validation_set/IMG_1823_10.JPG
#   inflating: validation_set/IMG_1823_10.xml
#   inflating: validation_set/IMG_1823_20.JPG
#   inflating: validation_set/IMG_1823_20.xml
#   inflating: validation_set/IMG_1823_22.JPG
#   inflating: validation_set/IMG_1823_22.xml
#   inflating: validation_set/IMG_1823_23.JPG
#   inflating: validation_set/IMG_1823_23.xml
#   inflating: validation_set/IMG_1823_28.JPG
#   inflating: validation_set/IMG_1823_28.xml
#   inflating: validation_set/IMG_1823_30.JPG
#   inflating: validation_set/IMG_1823_30.xml
#   inflating: validation_set/IMG_1823_31.JPG
#   inflating: validation_set/IMG_1823_31.xml
#   inflating: validation_set/IMG_1823_37.JPG
#   inflating: validation_set/IMG_1823_37.xml
#   inflating: validation_set/IMG_1823_40.JPG
#   inflating: validation_set/IMG_1823_40.xml
#   inflating: validation_set/IMG_1823_42.JPG
#   inflating: validation_set/IMG_1823_42.xml
#   inflating: validation_set/IMG_1825_06.JPG
#   inflating: validation_set/IMG_1825_06.xml
#   inflating: validation_set/IMG_1825_13.JPG
#   inflating: validation_set/IMG_1825_13.xml
#   inflating: validation_set/IMG_1825_16.JPG
#   inflating: validation_set/IMG_1825_16.xml
#   inflating: validation_set/IMG_1825_18.JPG
#   inflating: validation_set/IMG_1825_18.xml
#   inflating: validation_set/IMG_1825_27.JPG
#   inflating: validation_set/IMG_1825_27.xml
#   inflating: validation_set/IMG_1825_31.JPG
#   inflating: validation_set/IMG_1825_31.xml
#   inflating: validation_set/IMG_1825_34.JPG
#   inflating: validation_set/IMG_1825_34.xml
#   inflating: validation_set/IMG_1825_35.JPG
#   inflating: validation_set/IMG_1825_35.xml
#   inflating: validation_set/IMG_1825_39.JPG
#   inflating: validation_set/IMG_1825_39.xml
#   inflating: validation_set/IMG_1825_41.JPG
#   inflating: validation_set/IMG_1825_41.xml
#   inflating: validation_set/IMG_1825_42.JPG
#   inflating: validation_set/IMG_1825_42.xml
#   inflating: validation_set/IMG_1826_01.JPG
#   inflating: validation_set/IMG_1826_01.xml
#   inflating: validation_set/IMG_1826_03.JPG
#   inflating: validation_set/IMG_1826_03.xml
#   inflating: validation_set/IMG_1826_08.JPG
#   inflating: validation_set/IMG_1826_08.xml
#   inflating: validation_set/IMG_1826_09.JPG
#   inflating: validation_set/IMG_1826_09.xml
#   inflating: validation_set/IMG_1826_10.JPG
#   inflating: validation_set/IMG_1826_10.xml
#   inflating: validation_set/IMG_1826_11.JPG
#   inflating: validation_set/IMG_1826_11.xml
#   inflating: validation_set/IMG_1826_13.JPG
#   inflating: validation_set/IMG_1826_13.xml
#   inflating: validation_set/IMG_1826_17.JPG
#   inflating: validation_set/IMG_1826_17.xml
#   inflating: validation_set/IMG_1826_23.JPG
#   inflating: validation_set/IMG_1826_23.xml
#   inflating: validation_set/IMG_1826_26.JPG
#   inflating: validation_set/IMG_1826_26.xml
#   inflating: validation_set/IMG_1826_34.JPG
#   inflating: validation_set/IMG_1826_34.xml
#   inflating: validation_set/IMG_1826_36.JPG
#   inflating: validation_set/IMG_1826_36.xml
#   inflating: validation_set/IMG_1826_38.JPG
#   inflating: validation_set/IMG_1826_38.xml
#   inflating: validation_set/IMG_1826_42.JPG
#   inflating: validation_set/IMG_1826_42.xml
#   inflating: validation_set/IMG_1827_01.JPG
#   inflating: validation_set/IMG_1827_01.xml
#   inflating: validation_set/IMG_1827_03.JPG
#   inflating: validation_set/IMG_1827_03.xml
#   inflating: validation_set/IMG_1827_04.JPG
#   inflating: validation_set/IMG_1827_04.xml
#   inflating: validation_set/IMG_1827_06.JPG
#   inflating: validation_set/IMG_1827_06.xml
#   inflating: validation_set/IMG_1827_10.JPG
#   inflating: validation_set/IMG_1827_10.xml
#   inflating: validation_set/IMG_1827_11.JPG
#   inflating: validation_set/IMG_1827_11.xml
#   inflating: validation_set/IMG_1827_15.JPG
#   inflating: validation_set/IMG_1827_15.xml
#   inflating: validation_set/IMG_1827_26.JPG
#   inflating: validation_set/IMG_1827_26.xml
#   inflating: validation_set/IMG_1827_30.JPG
#   inflating: validation_set/IMG_1827_30.xml
#   inflating: validation_set/IMG_1827_31.JPG
#   inflating: validation_set/IMG_1827_31.xml
#   inflating: validation_set/IMG_1827_33.JPG
#   inflating: validation_set/IMG_1827_33.xml
#   inflating: validation_set/IMG_1827_41.JPG
#   inflating: validation_set/IMG_1827_41.xml
#   inflating: validation_set/IMG_1828_01.JPG
#   inflating: validation_set/IMG_1828_01.xml
#   inflating: validation_set/IMG_1828_03.JPG
#   inflating: validation_set/IMG_1828_03.xml
#   inflating: validation_set/IMG_1828_07.JPG
#   inflating: validation_set/IMG_1828_07.xml
#   inflating: validation_set/IMG_1828_10.JPG
#   inflating: validation_set/IMG_1828_10.xml
#   inflating: validation_set/IMG_1828_11.JPG
#   inflating: validation_set/IMG_1828_11.xml
#   inflating: validation_set/IMG_1828_13.JPG
#   inflating: validation_set/IMG_1828_13.xml
#   inflating: validation_set/IMG_1828_17.JPG
#   inflating: validation_set/IMG_1828_17.xml
#   inflating: validation_set/IMG_1828_25.JPG
#   inflating: validation_set/IMG_1828_25.xml
#   inflating: validation_set/IMG_1828_29.JPG
#   inflating: validation_set/IMG_1828_29.xml
#   inflating: validation_set/IMG_1828_30.JPG
#   inflating: validation_set/IMG_1828_30.xml
#   inflating: validation_set/IMG_1828_31.JPG
#   inflating: validation_set/IMG_1828_31.xml
#   inflating: validation_set/IMG_1828_33.JPG
#   inflating: validation_set/IMG_1828_33.xml
#   inflating: validation_set/IMG_1828_38.JPG
#   inflating: validation_set/IMG_1828_38.xml
#   inflating: validation_set/IMG_1830_05.JPG
#   inflating: validation_set/IMG_1830_05.xml
#   inflating: validation_set/IMG_1830_06.JPG
#   inflating: validation_set/IMG_1830_06.xml
#   inflating: validation_set/IMG_1830_07.JPG
#   inflating: validation_set/IMG_1830_07.xml
#   inflating: validation_set/IMG_1830_08.JPG
#   inflating: validation_set/IMG_1830_08.xml
#   inflating: validation_set/IMG_1830_13.JPG
#   inflating: validation_set/IMG_1830_13.xml
#   inflating: validation_set/IMG_1830_15.JPG
#   inflating: validation_set/IMG_1830_15.xml
#   inflating: validation_set/IMG_1830_21.JPG
#   inflating: validation_set/IMG_1830_21.xml
#   inflating: validation_set/IMG_1830_24.JPG
#   inflating: validation_set/IMG_1830_24.xml
#   inflating: validation_set/IMG_1830_28.JPG
#   inflating: validation_set/IMG_1830_28.xml
#   inflating: validation_set/IMG_1830_29.JPG
#   inflating: validation_set/IMG_1830_29.xml
#   inflating: validation_set/IMG_1830_30.JPG
#   inflating: validation_set/IMG_1830_30.xml
#   inflating: validation_set/IMG_1830_36.JPG
#   inflating: validation_set/IMG_1830_36.xml
#   inflating: validation_set/IMG_1830_37.JPG
#   inflating: validation_set/IMG_1830_37.xml
#   inflating: validation_set/IMG_1830_38.JPG
#   inflating: validation_set/IMG_1830_38.xml
#   inflating: validation_set/IMG_1831_06.JPG
#   inflating: validation_set/IMG_1831_06.xml
#   inflating: validation_set/IMG_1831_07.JPG
#   inflating: validation_set/IMG_1831_07.xml
#   inflating: validation_set/IMG_1831_09.JPG
#   inflating: validation_set/IMG_1831_09.xml
#   inflating: validation_set/IMG_1831_11.JPG
#   inflating: validation_set/IMG_1831_11.xml
#   inflating: validation_set/IMG_1831_12.JPG
#   inflating: validation_set/IMG_1831_12.xml
#   inflating: validation_set/IMG_1831_17.JPG
#   inflating: validation_set/IMG_1831_17.xml
#   inflating: validation_set/IMG_1831_23.JPG
#   inflating: validation_set/IMG_1831_23.xml
#   inflating: validation_set/IMG_1831_26.JPG
#   inflating: validation_set/IMG_1831_26.xml
#   inflating: validation_set/IMG_1831_29.JPG
#   inflating: validation_set/IMG_1831_29.xml
#   inflating: validation_set/IMG_1831_30.JPG
#   inflating: validation_set/IMG_1831_30.xml
#   inflating: validation_set/IMG_1831_34.JPG
#   inflating: validation_set/IMG_1831_34.xml
#   inflating: validation_set/IMG_1831_36.JPG
#   inflating: validation_set/IMG_1831_36.xml
#   inflating: validation_set/IMG_1831_42.JPG
#   inflating: validation_set/IMG_1831_42.xml
#   inflating: validation_set/IMG_1832_03.JPG
#   inflating: validation_set/IMG_1832_03.xml
#   inflating: validation_set/IMG_1832_06.JPG
#   inflating: validation_set/IMG_1832_06.xml
#   inflating: validation_set/IMG_1832_09.JPG
#   inflating: validation_set/IMG_1832_09.xml
#   inflating: validation_set/IMG_1832_10.JPG
#   inflating: validation_set/IMG_1832_10.xml
#   inflating: validation_set/IMG_1832_12.JPG
#   inflating: validation_set/IMG_1832_12.xml
#   inflating: validation_set/IMG_1832_13.JPG
#   inflating: validation_set/IMG_1832_13.xml
#   inflating: validation_set/IMG_1832_15.JPG
#   inflating: validation_set/IMG_1832_15.xml
#   inflating: validation_set/IMG_1832_16.JPG
#   inflating: validation_set/IMG_1832_16.xml
#   inflating: validation_set/IMG_1832_18.JPG
#   inflating: validation_set/IMG_1832_18.xml
#   inflating: validation_set/IMG_1832_21.JPG
#   inflating: validation_set/IMG_1832_21.xml
#   inflating: validation_set/IMG_1832_23.JPG
#   inflating: validation_set/IMG_1832_23.xml
#   inflating: validation_set/IMG_1832_24.JPG
#   inflating: validation_set/IMG_1832_24.xml
#   inflating: validation_set/IMG_1832_25.JPG
#   inflating: validation_set/IMG_1832_25.xml
#   inflating: validation_set/IMG_1832_26.JPG
#   inflating: validation_set/IMG_1832_26.xml
#   inflating: validation_set/IMG_1832_27.JPG
#   inflating: validation_set/IMG_1832_27.xml
#   inflating: validation_set/IMG_1832_29.JPG
#   inflating: validation_set/IMG_1832_29.xml
#   inflating: validation_set/IMG_1832_30.JPG
#   inflating: validation_set/IMG_1832_30.xml
#   inflating: validation_set/IMG_1832_41.JPG
#   inflating: validation_set/IMG_1832_41.xml
#   inflating: validation_set/IMG_1833_02.JPG
#   inflating: validation_set/IMG_1833_02.xml
#   inflating: validation_set/IMG_1833_12.JPG
#   inflating: validation_set/IMG_1833_12.xml
#   inflating: validation_set/IMG_1833_13.JPG
#   inflating: validation_set/IMG_1833_13.xml
#   inflating: validation_set/IMG_1833_18.JPG
#   inflating: validation_set/IMG_1833_18.xml
#   inflating: validation_set/IMG_1833_22.JPG
#   inflating: validation_set/IMG_1833_22.xml
#   inflating: validation_set/IMG_1833_30.JPG
#   inflating: validation_set/IMG_1833_30.xml
#   inflating: validation_set/IMG_1833_34.JPG
#   inflating: validation_set/IMG_1833_34.xml
#   inflating: validation_set/IMG_1833_35.JPG
#   inflating: validation_set/IMG_1833_35.xml
#   inflating: validation_set/IMG_1833_39.JPG
#   inflating: validation_set/IMG_1833_39.xml
#   inflating: validation_set/IMG_1833_42.JPG
#   inflating: validation_set/IMG_1833_42.xml
#   inflating: validation_set/IMG_1834_02.JPG
#   inflating: validation_set/IMG_1834_02.xml
#   inflating: validation_set/IMG_1834_05.JPG
#   inflating: validation_set/IMG_1834_05.xml
#   inflating: validation_set/IMG_1834_06.JPG
#   inflating: validation_set/IMG_1834_06.xml
#   inflating: validation_set/IMG_1834_10.JPG
#   inflating: validation_set/IMG_1834_10.xml
#   inflating: validation_set/IMG_1834_12.JPG
#   inflating: validation_set/IMG_1834_12.xml
#   inflating: validation_set/IMG_1834_13.JPG
#   inflating: validation_set/IMG_1834_13.xml
#   inflating: validation_set/IMG_1834_18.JPG
#   inflating: validation_set/IMG_1834_18.xml
#   inflating: validation_set/IMG_1834_24.JPG
#   inflating: validation_set/IMG_1834_24.xml
#   inflating: validation_set/IMG_1834_26.JPG
#   inflating: validation_set/IMG_1834_26.xml
#   inflating: validation_set/IMG_1834_32.JPG
#   inflating: validation_set/IMG_1834_32.xml
#   inflating: validation_set/IMG_1834_34.JPG
#   inflating: validation_set/IMG_1834_34.xml
#   inflating: validation_set/IMG_1834_39.JPG
#   inflating: validation_set/IMG_1834_39.xml
#   inflating: validation_set/IMG_1834_40.JPG
#   inflating: validation_set/IMG_1834_40.xml
#   inflating: validation_set/IMG_1834_42.JPG
#   inflating: validation_set/IMG_1834_42.xml
#   inflating: validation_set/IMG_1836_01.JPG
#   inflating: validation_set/IMG_1836_01.xml
#   inflating: validation_set/IMG_1836_04.JPG
#   inflating: validation_set/IMG_1836_04.xml
#   inflating: validation_set/IMG_1836_06.JPG
#   inflating: validation_set/IMG_1836_06.xml
#   inflating: validation_set/IMG_1836_07.JPG
#   inflating: validation_set/IMG_1836_07.xml
#   inflating: validation_set/IMG_1836_13.JPG
#   inflating: validation_set/IMG_1836_13.xml
#   inflating: validation_set/IMG_1836_18.JPG
#   inflating: validation_set/IMG_1836_18.xml
#   inflating: validation_set/IMG_1836_23.JPG
#   inflating: validation_set/IMG_1836_23.xml
#   inflating: validation_set/IMG_1836_29.JPG
#   inflating: validation_set/IMG_1836_29.xml
#   inflating: validation_set/IMG_1836_30.JPG
#   inflating: validation_set/IMG_1836_30.xml
#   inflating: validation_set/IMG_1836_35.JPG
#   inflating: validation_set/IMG_1836_35.xml
#   inflating: validation_set/IMG_1836_36.JPG
#   inflating: validation_set/IMG_1836_36.xml
#   inflating: validation_set/IMG_1836_42.JPG
#   inflating: validation_set/IMG_1836_42.xml
#   inflating: validation_set/IMG_1837_02.JPG
#   inflating: validation_set/IMG_1837_02.xml
#   inflating: validation_set/IMG_1837_03.JPG
#   inflating: validation_set/IMG_1837_03.xml
#   inflating: validation_set/IMG_1837_05.JPG
#   inflating: validation_set/IMG_1837_05.xml
#   inflating: validation_set/IMG_1837_09.JPG
#   inflating: validation_set/IMG_1837_09.xml
#   inflating: validation_set/IMG_1837_13.JPG
#   inflating: validation_set/IMG_1837_13.xml
#   inflating: validation_set/IMG_1837_15.JPG
#   inflating: validation_set/IMG_1837_15.xml
#   inflating: validation_set/IMG_1837_21.JPG
#   inflating: validation_set/IMG_1837_21.xml
#   inflating: validation_set/IMG_1837_22.JPG
#   inflating: validation_set/IMG_1837_22.xml
#   inflating: validation_set/IMG_1837_23.JPG
#   inflating: validation_set/IMG_1837_23.xml
#   inflating: validation_set/IMG_1837_25.JPG
#   inflating: validation_set/IMG_1837_25.xml
#   inflating: validation_set/IMG_1837_26.JPG
#   inflating: validation_set/IMG_1837_26.xml
#   inflating: validation_set/IMG_1837_27.JPG
#   inflating: validation_set/IMG_1837_27.xml
#   inflating: validation_set/IMG_1837_28.JPG
#   inflating: validation_set/IMG_1837_28.xml
#   inflating: validation_set/IMG_1837_29.JPG
#   inflating: validation_set/IMG_1837_29.xml
#   inflating: validation_set/IMG_1837_32.JPG
#   inflating: validation_set/IMG_1837_32.xml
#   inflating: validation_set/IMG_1837_33.JPG
#   inflating: validation_set/IMG_1837_33.xml
#   inflating: validation_set/IMG_1837_34.JPG
#   inflating: validation_set/IMG_1837_34.xml
#   inflating: validation_set/IMG_1837_35.JPG
#   inflating: validation_set/IMG_1837_35.xml
#   inflating: validation_set/IMG_1838_04.JPG
#   inflating: validation_set/IMG_1838_04.xml
#   inflating: validation_set/IMG_1838_06.JPG
#   inflating: validation_set/IMG_1838_06.xml
#   inflating: validation_set/IMG_1838_08.JPG
#   inflating: validation_set/IMG_1838_08.xml
#   inflating: validation_set/IMG_1838_13.JPG
#   inflating: validation_set/IMG_1838_13.xml
#   inflating: validation_set/IMG_1838_16.JPG
#   inflating: validation_set/IMG_1838_16.xml
#   inflating: validation_set/IMG_1838_19.JPG
#   inflating: validation_set/IMG_1838_19.xml
#   inflating: validation_set/IMG_1838_20.JPG
#   inflating: validation_set/IMG_1838_20.xml
#   inflating: validation_set/IMG_1838_21.JPG
#   inflating: validation_set/IMG_1838_21.xml
#   inflating: validation_set/IMG_1838_22.JPG
#   inflating: validation_set/IMG_1838_22.xml
#   inflating: validation_set/IMG_1838_24.JPG
#   inflating: validation_set/IMG_1838_24.xml
#   inflating: validation_set/IMG_1838_25.JPG
#   inflating: validation_set/IMG_1838_25.xml
#   inflating: validation_set/IMG_1838_28.JPG
#   inflating: validation_set/IMG_1838_28.xml
#   inflating: validation_set/IMG_1838_29.JPG
#   inflating: validation_set/IMG_1838_29.xml
#   inflating: validation_set/IMG_1838_30.JPG
#   inflating: validation_set/IMG_1838_30.xml
#   inflating: validation_set/IMG_1838_32.JPG
#   inflating: validation_set/IMG_1838_32.xml
#   inflating: validation_set/IMG_1838_40.JPG
#   inflating: validation_set/IMG_1838_40.xml
#   inflating: validation_set/IMG_1838_42.JPG
#   inflating: validation_set/IMG_1838_42.xml
#   inflating: validation_set/IMG_1842_02.JPG
#   inflating: validation_set/IMG_1842_02.xml
#   inflating: validation_set/IMG_1842_03.JPG
#   inflating: validation_set/IMG_1842_03.xml
#   inflating: validation_set/IMG_1842_07.JPG
#   inflating: validation_set/IMG_1842_07.xml
#   inflating: validation_set/IMG_1842_08.JPG
#   inflating: validation_set/IMG_1842_08.xml
#   inflating: validation_set/IMG_1842_09.JPG
#   inflating: validation_set/IMG_1842_09.xml
#   inflating: validation_set/IMG_1842_11.JPG
#   inflating: validation_set/IMG_1842_11.xml
#   inflating: validation_set/IMG_1842_16.JPG
#   inflating: validation_set/IMG_1842_16.xml
#   inflating: validation_set/IMG_1842_17.JPG
#   inflating: validation_set/IMG_1842_17.xml
#   inflating: validation_set/IMG_1842_19.JPG
#   inflating: validation_set/IMG_1842_19.xml
#   inflating: validation_set/IMG_1842_21.JPG
#   inflating: validation_set/IMG_1842_21.xml
#   inflating: validation_set/IMG_1842_27.JPG
#   inflating: validation_set/IMG_1842_27.xml
#   inflating: validation_set/IMG_1842_28.JPG
#   inflating: validation_set/IMG_1842_28.xml
#   inflating: validation_set/IMG_1842_32.JPG
#   inflating: validation_set/IMG_1842_32.xml
#   inflating: validation_set/IMG_1842_33.JPG
#   inflating: validation_set/IMG_1842_33.xml
#   inflating: validation_set/IMG_1842_38.JPG
#   inflating: validation_set/IMG_1842_38.xml
#   inflating: validation_set/IMG_1842_42.JPG
#   inflating: validation_set/IMG_1842_42.xml
#   inflating: validation_set/IMG_1843_01.JPG
#   inflating: validation_set/IMG_1843_01.xml
#   inflating: validation_set/IMG_1843_05.JPG
#   inflating: validation_set/IMG_1843_05.xml
#   inflating: validation_set/IMG_1843_09.JPG
#   inflating: validation_set/IMG_1843_09.xml
#   inflating: validation_set/IMG_1843_12.JPG
#   inflating: validation_set/IMG_1843_12.xml
#   inflating: validation_set/IMG_1843_13.JPG
#   inflating: validation_set/IMG_1843_13.xml
#   inflating: validation_set/IMG_1843_27.JPG
#   inflating: validation_set/IMG_1843_27.xml
#   inflating: validation_set/IMG_1843_31.JPG
#   inflating: validation_set/IMG_1843_31.xml
#   inflating: validation_set/IMG_1843_33.JPG
#   inflating: validation_set/IMG_1843_33.xml
#   inflating: validation_set/IMG_1843_34.JPG
#   inflating: validation_set/IMG_1843_34.xml
#   inflating: validation_set/IMG_1843_39.JPG
#   inflating: validation_set/IMG_1843_39.xml
#   inflating: validation_set/IMG_1843_40.JPG
#   inflating: validation_set/IMG_1843_40.xml
#   inflating: validation_set/IMG_1843_41.JPG
#   inflating: validation_set/IMG_1843_41.xml
#   inflating: validation_set/IMG_1843_42.JPG
#   inflating: validation_set/IMG_1843_42.xml
#   inflating: validation_set/IMG_1844_02.JPG
#   inflating: validation_set/IMG_1844_02.xml
#   inflating: validation_set/IMG_1844_06.JPG
#   inflating: validation_set/IMG_1844_06.xml
#   inflating: validation_set/IMG_1844_11.JPG
#   inflating: validation_set/IMG_1844_11.xml
#   inflating: validation_set/IMG_1844_16.JPG
#   inflating: validation_set/IMG_1844_16.xml
#   inflating: validation_set/IMG_1844_19.JPG
#   inflating: validation_set/IMG_1844_19.xml
#   inflating: validation_set/IMG_1844_22.JPG
#   inflating: validation_set/IMG_1844_22.xml
#   inflating: validation_set/IMG_1844_24.JPG
#   inflating: validation_set/IMG_1844_24.xml
#   inflating: validation_set/IMG_1844_25.JPG
#   inflating: validation_set/IMG_1844_25.xml
#   inflating: validation_set/IMG_1844_28.JPG
#   inflating: validation_set/IMG_1844_28.xml
#   inflating: validation_set/IMG_1844_31.JPG
#   inflating: validation_set/IMG_1844_31.xml
#   inflating: validation_set/IMG_1844_37.JPG
#   inflating: validation_set/IMG_1844_37.xml
#   inflating: validation_set/IMG_1844_40.JPG
#   inflating: validation_set/IMG_1844_40.xml
#   inflating: validation_set/IMG_1848_01.JPG
#   inflating: validation_set/IMG_1848_01.xml
#   inflating: validation_set/IMG_1848_02.JPG
#   inflating: validation_set/IMG_1848_02.xml
#   inflating: validation_set/IMG_1848_06.JPG
#   inflating: validation_set/IMG_1848_06.xml
#   inflating: validation_set/IMG_1848_09.JPG
#   inflating: validation_set/IMG_1848_09.xml
#   inflating: validation_set/IMG_1848_11.JPG
#   inflating: validation_set/IMG_1848_11.xml
#   inflating: validation_set/IMG_1848_14.JPG
#   inflating: validation_set/IMG_1848_14.xml
#   inflating: validation_set/IMG_1848_15.JPG
#   inflating: validation_set/IMG_1848_15.xml
#   inflating: validation_set/IMG_1848_17.JPG
#   inflating: validation_set/IMG_1848_17.xml
#   inflating: validation_set/IMG_1848_18.JPG
#   inflating: validation_set/IMG_1848_18.xml
#   inflating: validation_set/IMG_1848_22.JPG
#   inflating: validation_set/IMG_1848_22.xml
#   inflating: validation_set/IMG_1848_24.JPG
#   inflating: validation_set/IMG_1848_24.xml
#   inflating: validation_set/IMG_1848_28.JPG
#   inflating: validation_set/IMG_1848_28.xml
#   inflating: validation_set/IMG_1848_35.JPG
#   inflating: validation_set/IMG_1848_35.xml
#   inflating: validation_set/IMG_1848_39.JPG
#   inflating: validation_set/IMG_1848_39.xml
#   inflating: validation_set/IMG_1848_40.JPG
#   inflating: validation_set/IMG_1848_40.xml
#   inflating: validation_set/IMG_1850_04.JPG
#   inflating: validation_set/IMG_1850_04.xml
#   inflating: validation_set/IMG_1850_08.JPG
#   inflating: validation_set/IMG_1850_08.xml
#   inflating: validation_set/IMG_1850_09.JPG
#   inflating: validation_set/IMG_1850_09.xml
#   inflating: validation_set/IMG_1850_13.JPG
#   inflating: validation_set/IMG_1850_13.xml
#   inflating: validation_set/IMG_1850_23.JPG
#   inflating: validation_set/IMG_1850_23.xml
#   inflating: validation_set/IMG_1850_24.JPG
#   inflating: validation_set/IMG_1850_24.xml
#   inflating: validation_set/IMG_1850_27.JPG
#   inflating: validation_set/IMG_1850_27.xml
#   inflating: validation_set/IMG_1850_34.JPG
#   inflating: validation_set/IMG_1850_34.xml
#   inflating: validation_set/IMG_1850_36.JPG
#   inflating: validation_set/IMG_1850_36.xml
#   inflating: validation_set/IMG_1850_37.JPG
#   inflating: validation_set/IMG_1850_37.xml
#   inflating: validation_set/IMG_1850_39.JPG
#   inflating: validation_set/IMG_1850_39.xml
#   inflating: validation_set/IMG_1850_42.JPG
#   inflating: validation_set/IMG_1850_42.xml
#   inflating: validation_set/IMG_1851_03.JPG
#   inflating: validation_set/IMG_1851_03.xml
#   inflating: validation_set/IMG_1851_07.JPG
#   inflating: validation_set/IMG_1851_07.xml
#   inflating: validation_set/IMG_1851_09.JPG
#   inflating: validation_set/IMG_1851_09.xml
#   inflating: validation_set/IMG_1851_11.JPG
#   inflating: validation_set/IMG_1851_11.xml
#   inflating: validation_set/IMG_1851_14.JPG
#   inflating: validation_set/IMG_1851_14.xml
#   inflating: validation_set/IMG_1851_24.JPG
#   inflating: validation_set/IMG_1851_24.xml
#   inflating: validation_set/IMG_1851_37.JPG
#   inflating: validation_set/IMG_1851_37.xml
#   inflating: validation_set/IMG_1852_01.JPG
#   inflating: validation_set/IMG_1852_01.xml
#   inflating: validation_set/IMG_1852_04.JPG
#   inflating: validation_set/IMG_1852_04.xml
#   inflating: validation_set/IMG_1852_11.JPG
#   inflating: validation_set/IMG_1852_11.xml
#   inflating: validation_set/IMG_1852_15.JPG
#   inflating: validation_set/IMG_1852_15.xml
#   inflating: validation_set/IMG_1852_18.JPG
#   inflating: validation_set/IMG_1852_18.xml
#   inflating: validation_set/IMG_1852_20.JPG
#   inflating: validation_set/IMG_1852_20.xml
#   inflating: validation_set/IMG_1852_24.JPG
#   inflating: validation_set/IMG_1852_24.xml
#   inflating: validation_set/IMG_1852_29.JPG
#   inflating: validation_set/IMG_1852_29.xml
#   inflating: validation_set/IMG_1852_30.JPG
#   inflating: validation_set/IMG_1852_30.xml
#   inflating: validation_set/IMG_1852_31.JPG
#   inflating: validation_set/IMG_1852_31.xml
#   inflating: validation_set/IMG_1852_40.JPG
#   inflating: validation_set/IMG_1852_40.xml
#   inflating: validation_set/IMG_1853_02.JPG
#   inflating: validation_set/IMG_1853_02.xml
#   inflating: validation_set/IMG_1853_04.JPG
#   inflating: validation_set/IMG_1853_04.xml
#   inflating: validation_set/IMG_1853_08.JPG
#   inflating: validation_set/IMG_1853_08.xml
#   inflating: validation_set/IMG_1853_13.JPG
#   inflating: validation_set/IMG_1853_13.xml
#   inflating: validation_set/IMG_1853_19.JPG
#   inflating: validation_set/IMG_1853_19.xml
#   inflating: validation_set/IMG_1853_20.JPG
#   inflating: validation_set/IMG_1853_20.xml
#   inflating: validation_set/IMG_1853_22.JPG
#   inflating: validation_set/IMG_1853_22.xml
#   inflating: validation_set/IMG_1853_25.JPG
#   inflating: validation_set/IMG_1853_25.xml
#   inflating: validation_set/IMG_1853_31.JPG
#   inflating: validation_set/IMG_1853_31.xml
#   inflating: validation_set/IMG_1853_33.JPG
#   inflating: validation_set/IMG_1853_33.xml
#   inflating: validation_set/IMG_1853_42.JPG
#   inflating: validation_set/IMG_1853_42.xml
#   inflating: validation_set/IMG_1855_08.JPG
#   inflating: validation_set/IMG_1855_08.xml
#   inflating: validation_set/IMG_1855_10.JPG
#   inflating: validation_set/IMG_1855_10.xml
#   inflating: validation_set/IMG_1855_14.JPG
#   inflating: validation_set/IMG_1855_14.xml
#   inflating: validation_set/IMG_1855_15.JPG
#   inflating: validation_set/IMG_1855_15.xml
#   inflating: validation_set/IMG_1855_17.JPG
#   inflating: validation_set/IMG_1855_17.xml
#   inflating: validation_set/IMG_1855_29.JPG
#   inflating: validation_set/IMG_1855_29.xml
#   inflating: validation_set/IMG_1855_30.JPG
#   inflating: validation_set/IMG_1855_30.xml
#   inflating: validation_set/IMG_1855_32.JPG
#   inflating: validation_set/IMG_1855_32.xml
#   inflating: validation_set/IMG_1855_34.JPG
#   inflating: validation_set/IMG_1855_34.xml
#   inflating: validation_set/IMG_1855_36.JPG
#   inflating: validation_set/IMG_1855_36.xml
#   inflating: validation_set/IMG_1855_40.JPG
#   inflating: validation_set/IMG_1855_40.xml
#   inflating: validation_set/IMG_1855_42.JPG
#   inflating: validation_set/IMG_1855_42.xml
#   inflating: validation_set/IMG_1856_06.JPG
#   inflating: validation_set/IMG_1856_06.xml
#   inflating: validation_set/IMG_1856_08.JPG
#   inflating: validation_set/IMG_1856_08.xml
#   inflating: validation_set/IMG_1856_09.JPG
#   inflating: validation_set/IMG_1856_09.xml
#   inflating: validation_set/IMG_1856_13.JPG
#   inflating: validation_set/IMG_1856_13.xml
#   inflating: validation_set/IMG_1856_21.JPG
#   inflating: validation_set/IMG_1856_21.xml
#   inflating: validation_set/IMG_1856_27.JPG
#   inflating: validation_set/IMG_1856_27.xml
#   inflating: validation_set/IMG_1856_28.JPG
#   inflating: validation_set/IMG_1856_28.xml
#   inflating: validation_set/IMG_1856_33.JPG
#   inflating: validation_set/IMG_1856_33.xml
#   inflating: validation_set/IMG_1856_39.JPG
#   inflating: validation_set/IMG_1856_39.xml
#   inflating: validation_set/IMG_1856_41.JPG
#   inflating: validation_set/IMG_1856_41.xml
#   inflating: validation_set/IMG_1860_05.JPG
#   inflating: validation_set/IMG_1860_05.xml
#   inflating: validation_set/IMG_1860_06.JPG
#   inflating: validation_set/IMG_1860_06.xml
#   inflating: validation_set/IMG_1860_09.JPG
#   inflating: validation_set/IMG_1860_09.xml
#   inflating: validation_set/IMG_1860_15.JPG
#   inflating: validation_set/IMG_1860_15.xml
#   inflating: validation_set/IMG_1860_16.JPG
#   inflating: validation_set/IMG_1860_16.xml
#   inflating: validation_set/IMG_1860_17.JPG
#   inflating: validation_set/IMG_1860_17.xml
#   inflating: validation_set/IMG_1860_23.JPG
#   inflating: validation_set/IMG_1860_23.xml
#   inflating: validation_set/IMG_1860_27.JPG
#   inflating: validation_set/IMG_1860_27.xml
#   inflating: validation_set/IMG_1860_28.JPG
#   inflating: validation_set/IMG_1860_28.xml
#   inflating: validation_set/IMG_1860_30.JPG
#   inflating: validation_set/IMG_1860_30.xml
#   inflating: validation_set/IMG_1860_34.JPG
#   inflating: validation_set/IMG_1860_34.xml
#   inflating: validation_set/IMG_1860_39.JPG
#   inflating: validation_set/IMG_1860_39.xml
#   inflating: validation_set/IMG_1860_40.JPG
#   inflating: validation_set/IMG_1860_40.xml
#   inflating: validation_set/IMG_1861_01.JPG
#   inflating: validation_set/IMG_1861_01.xml
#   inflating: validation_set/IMG_1861_04.JPG
#   inflating: validation_set/IMG_1861_04.xml
#   inflating: validation_set/IMG_1861_10.JPG
#   inflating: validation_set/IMG_1861_10.xml
#   inflating: validation_set/IMG_1861_18.JPG
#   inflating: validation_set/IMG_1861_18.xml
#   inflating: validation_set/IMG_1861_19.JPG
#   inflating: validation_set/IMG_1861_19.xml
#   inflating: validation_set/IMG_1861_21.JPG
#   inflating: validation_set/IMG_1861_21.xml
#   inflating: validation_set/IMG_1861_23.JPG
#   inflating: validation_set/IMG_1861_23.xml
#   inflating: validation_set/IMG_1861_24.JPG
#   inflating: validation_set/IMG_1861_24.xml
#   inflating: validation_set/IMG_1861_28.JPG
#   inflating: validation_set/IMG_1861_28.xml
#   inflating: validation_set/IMG_1861_32.JPG
#   inflating: validation_set/IMG_1861_32.xml
#   inflating: validation_set/IMG_1861_35.JPG
#   inflating: validation_set/IMG_1861_35.xml
#   inflating: validation_set/IMG_1861_36.JPG
#   inflating: validation_set/IMG_1861_36.xml
#   inflating: validation_set/IMG_1861_37.JPG
#   inflating: validation_set/IMG_1861_37.xml
#   inflating: validation_set/IMG_1862_01.JPG
#   inflating: validation_set/IMG_1862_01.xml
#   inflating: validation_set/IMG_1862_04.JPG
#   inflating: validation_set/IMG_1862_04.xml
#   inflating: validation_set/IMG_1862_05.JPG
#   inflating: validation_set/IMG_1862_05.xml
#   inflating: validation_set/IMG_1862_06.JPG
#   inflating: validation_set/IMG_1862_06.xml
#   inflating: validation_set/IMG_1862_13.JPG
#   inflating: validation_set/IMG_1862_13.xml
#   inflating: validation_set/IMG_1862_15.JPG
#   inflating: validation_set/IMG_1862_15.xml
#   inflating: validation_set/IMG_1862_16.JPG
#   inflating: validation_set/IMG_1862_16.xml
#   inflating: validation_set/IMG_1862_18.JPG
#   inflating: validation_set/IMG_1862_18.xml
#   inflating: validation_set/IMG_1862_19.JPG
#   inflating: validation_set/IMG_1862_19.xml
#   inflating: validation_set/IMG_1862_27.JPG
#   inflating: validation_set/IMG_1862_27.xml
#   inflating: validation_set/IMG_1862_36.JPG
#   inflating: validation_set/IMG_1862_36.xml
#   inflating: validation_set/IMG_1862_40.JPG
#   inflating: validation_set/IMG_1862_40.xml
#   inflating: validation_set/IMG_1862_41.JPG
#   inflating: validation_set/IMG_1862_41.xml
#   inflating: validation_set/IMG_1862_42.JPG
#   inflating: validation_set/IMG_1862_42.xml
#   inflating: validation_set/IMG_1863_01.JPG
#   inflating: validation_set/IMG_1863_01.xml
#   inflating: validation_set/IMG_1863_03.JPG
#   inflating: validation_set/IMG_1863_03.xml
#   inflating: validation_set/IMG_1863_04.JPG
#   inflating: validation_set/IMG_1863_04.xml
#   inflating: validation_set/IMG_1863_09.JPG
#   inflating: validation_set/IMG_1863_09.xml
#   inflating: validation_set/IMG_1863_10.JPG
#   inflating: validation_set/IMG_1863_10.xml
#   inflating: validation_set/IMG_1863_12.JPG
#   inflating: validation_set/IMG_1863_12.xml
#   inflating: validation_set/IMG_1863_13.JPG
#   inflating: validation_set/IMG_1863_13.xml
#   inflating: validation_set/IMG_1863_21.JPG
#   inflating: validation_set/IMG_1863_21.xml
#   inflating: validation_set/IMG_1863_23.JPG
#   inflating: validation_set/IMG_1863_23.xml
#   inflating: validation_set/IMG_1863_28.JPG
#   inflating: validation_set/IMG_1863_28.xml
#   inflating: validation_set/IMG_1863_33.JPG
#   inflating: validation_set/IMG_1863_33.xml
#   inflating: validation_set/IMG_1863_34.JPG
#   inflating: validation_set/IMG_1863_34.xml
#   inflating: validation_set/IMG_1863_38.JPG
#   inflating: validation_set/IMG_1863_38.xml
#   inflating: validation_set/IMG_1863_41.JPG
#   inflating: validation_set/IMG_1863_41.xml
#   inflating: validation_set/IMG_1864_03.JPG
#   inflating: validation_set/IMG_1864_03.xml
#   inflating: validation_set/IMG_1864_08.JPG
#   inflating: validation_set/IMG_1864_08.xml
#   inflating: validation_set/IMG_1864_09.JPG
#   inflating: validation_set/IMG_1864_09.xml
#   inflating: validation_set/IMG_1864_10.JPG
#   inflating: validation_set/IMG_1864_10.xml
#   inflating: validation_set/IMG_1864_16.JPG
#   inflating: validation_set/IMG_1864_16.xml
#   inflating: validation_set/IMG_1864_20.JPG
#   inflating: validation_set/IMG_1864_20.xml
#   inflating: validation_set/IMG_1864_26.JPG
#   inflating: validation_set/IMG_1864_26.xml
#   inflating: validation_set/IMG_1864_27.JPG
#   inflating: validation_set/IMG_1864_27.xml
#   inflating: validation_set/IMG_1864_31.JPG
#   inflating: validation_set/IMG_1864_31.xml
#   inflating: validation_set/IMG_1864_32.JPG
#   inflating: validation_set/IMG_1864_32.xml
#   inflating: validation_set/IMG_1864_34.JPG
#   inflating: validation_set/IMG_1864_34.xml
#   inflating: validation_set/IMG_1864_37.JPG
#   inflating: validation_set/IMG_1864_37.xml
#   inflating: validation_set/IMG_1864_39.JPG
#   inflating: validation_set/IMG_1864_39.xml
#   inflating: validation_set/IMG_1866_09.JPG
#   inflating: validation_set/IMG_1866_09.xml
#   inflating: validation_set/IMG_1866_13.JPG
#   inflating: validation_set/IMG_1866_13.xml
#   inflating: validation_set/IMG_1866_15.JPG
#   inflating: validation_set/IMG_1866_15.xml
#   inflating: validation_set/IMG_1866_17.JPG
#   inflating: validation_set/IMG_1866_17.xml
#   inflating: validation_set/IMG_1866_18.JPG
#   inflating: validation_set/IMG_1866_18.xml
#   inflating: validation_set/IMG_1866_19.JPG
#   inflating: validation_set/IMG_1866_19.xml
#   inflating: validation_set/IMG_1866_21.JPG
#   inflating: validation_set/IMG_1866_21.xml
#   inflating: validation_set/IMG_1866_22.JPG
#   inflating: validation_set/IMG_1866_22.xml
#   inflating: validation_set/IMG_1866_24.JPG
#   inflating: validation_set/IMG_1866_24.xml
#   inflating: validation_set/IMG_1866_25.JPG
#   inflating: validation_set/IMG_1866_25.xml
#   inflating: validation_set/IMG_1866_26.JPG
#   inflating: validation_set/IMG_1866_26.xml
#   inflating: validation_set/IMG_1866_27.JPG
#   inflating: validation_set/IMG_1866_27.xml
#   inflating: validation_set/IMG_1866_35.JPG
#   inflating: validation_set/IMG_1866_35.xml
#   inflating: validation_set/IMG_1866_41.JPG
#   inflating: validation_set/IMG_1866_41.xml
#   inflating: validation_set/IMG_1867_05.JPG
#   inflating: validation_set/IMG_1867_05.xml
#   inflating: validation_set/IMG_1867_06.JPG
#   inflating: validation_set/IMG_1867_06.xml
#   inflating: validation_set/IMG_1867_10.JPG
#   inflating: validation_set/IMG_1867_10.xml
#   inflating: validation_set/IMG_1867_14.JPG
#   inflating: validation_set/IMG_1867_14.xml
#   inflating: validation_set/IMG_1867_15.JPG
#   inflating: validation_set/IMG_1867_15.xml
#   inflating: validation_set/IMG_1867_27.JPG
#   inflating: validation_set/IMG_1867_27.xml
#   inflating: validation_set/IMG_1867_30.JPG
#   inflating: validation_set/IMG_1867_30.xml
#   inflating: validation_set/IMG_1867_31.JPG
#   inflating: validation_set/IMG_1867_31.xml
#   inflating: validation_set/IMG_1867_32.JPG
#   inflating: validation_set/IMG_1867_32.xml
#   inflating: validation_set/IMG_1867_33.JPG
#   inflating: validation_set/IMG_1867_33.xml
#   inflating: validation_set/IMG_1867_37.JPG
#   inflating: validation_set/IMG_1867_37.xml
#   inflating: validation_set/IMG_1867_38.JPG
#   inflating: validation_set/IMG_1867_38.xml
#   inflating: validation_set/IMG_1871_01.JPG
#   inflating: validation_set/IMG_1871_01.xml
#   inflating: validation_set/IMG_1871_04.JPG
#   inflating: validation_set/IMG_1871_04.xml
#   inflating: validation_set/IMG_1871_09.JPG
#   inflating: validation_set/IMG_1871_09.xml
#   inflating: validation_set/IMG_1871_10.JPG
#   inflating: validation_set/IMG_1871_10.xml
#   inflating: validation_set/IMG_1871_17.JPG
#   inflating: validation_set/IMG_1871_17.xml
#   inflating: validation_set/IMG_1871_18.JPG
#   inflating: validation_set/IMG_1871_18.xml
#   inflating: validation_set/IMG_1871_20.JPG
#   inflating: validation_set/IMG_1871_20.xml
#   inflating: validation_set/IMG_1871_29.JPG
#   inflating: validation_set/IMG_1871_29.xml
#   inflating: validation_set/IMG_1871_31.JPG
#   inflating: validation_set/IMG_1871_31.xml
#   inflating: validation_set/IMG_1871_33.JPG
#   inflating: validation_set/IMG_1871_33.xml
#   inflating: validation_set/IMG_1871_34.JPG
#   inflating: validation_set/IMG_1871_34.xml
#   inflating: validation_set/IMG_1871_35.JPG
#   inflating: validation_set/IMG_1871_35.xml
#   inflating: validation_set/IMG_1871_36.JPG
#   inflating: validation_set/IMG_1871_36.xml
#   inflating: validation_set/IMG_1871_39.JPG
#   inflating: validation_set/IMG_1871_39.xml
#   inflating: validation_set/IMG_1874_04.JPG
#   inflating: validation_set/IMG_1874_04.xml
#   inflating: validation_set/IMG_1874_06.JPG
#   inflating: validation_set/IMG_1874_06.xml
#   inflating: validation_set/IMG_1874_08.JPG
#   inflating: validation_set/IMG_1874_08.xml
#   inflating: validation_set/IMG_1874_10.JPG
#   inflating: validation_set/IMG_1874_10.xml
#   inflating: validation_set/IMG_1874_14.JPG
#   inflating: validation_set/IMG_1874_14.xml
#   inflating: validation_set/IMG_1874_16.JPG
#   inflating: validation_set/IMG_1874_16.xml
#   inflating: validation_set/IMG_1874_17.JPG
#   inflating: validation_set/IMG_1874_17.xml
#   inflating: validation_set/IMG_1874_18.JPG
#   inflating: validation_set/IMG_1874_18.xml
#   inflating: validation_set/IMG_1874_19.JPG
#   inflating: validation_set/IMG_1874_19.xml
#   inflating: validation_set/IMG_1874_22.JPG
#   inflating: validation_set/IMG_1874_22.xml
#   inflating: validation_set/IMG_1874_27.JPG
#   inflating: validation_set/IMG_1874_27.xml
#   inflating: validation_set/IMG_1874_28.JPG
#   inflating: validation_set/IMG_1874_28.xml
#   inflating: validation_set/IMG_1874_32.JPG
#   inflating: validation_set/IMG_1874_32.xml
#   inflating: validation_set/IMG_1874_40.JPG
#   inflating: validation_set/IMG_1874_40.xml
#   inflating: validation_set/IMG_1874_42.JPG
#   inflating: validation_set/IMG_1874_42.xml
#   inflating: validation_set/IMG_1875_01.JPG
#   inflating: validation_set/IMG_1875_01.xml
#   inflating: validation_set/IMG_1875_02.JPG
#   inflating: validation_set/IMG_1875_02.xml
#   inflating: validation_set/IMG_1875_04.JPG
#   inflating: validation_set/IMG_1875_04.xml
#   inflating: validation_set/IMG_1875_08.JPG
#   inflating: validation_set/IMG_1875_08.xml
#   inflating: validation_set/IMG_1875_15.JPG
#   inflating: validation_set/IMG_1875_15.xml
#   inflating: validation_set/IMG_1875_21.JPG
#   inflating: validation_set/IMG_1875_21.xml
#   inflating: validation_set/IMG_1875_22.JPG
#   inflating: validation_set/IMG_1875_22.xml
#   inflating: validation_set/IMG_1875_32.JPG
#   inflating: validation_set/IMG_1875_32.xml
#   inflating: validation_set/IMG_1875_35.JPG
#   inflating: validation_set/IMG_1875_35.xml
#   inflating: validation_set/IMG_1875_37.JPG
#   inflating: validation_set/IMG_1875_37.xml
#   inflating: validation_set/IMG_1877_03.JPG
#   inflating: validation_set/IMG_1877_03.xml
#   inflating: validation_set/IMG_1877_09.JPG
#   inflating: validation_set/IMG_1877_09.xml
#   inflating: validation_set/IMG_1877_14.JPG
#   inflating: validation_set/IMG_1877_14.xml
#   inflating: validation_set/IMG_1877_16.JPG
#   inflating: validation_set/IMG_1877_16.xml
#   inflating: validation_set/IMG_1877_27.JPG
#   inflating: validation_set/IMG_1877_27.xml
#   inflating: validation_set/IMG_1877_28.JPG
#   inflating: validation_set/IMG_1877_28.xml
#   inflating: validation_set/IMG_1877_29.JPG
#   inflating: validation_set/IMG_1877_29.xml
#   inflating: validation_set/IMG_1877_32.JPG
#   inflating: validation_set/IMG_1877_32.xml
#   inflating: validation_set/IMG_1877_33.JPG
#   inflating: validation_set/IMG_1877_33.xml
#   inflating: validation_set/IMG_1877_34.JPG
#   inflating: validation_set/IMG_1877_34.xml
#   inflating: validation_set/IMG_1877_36.JPG
#   inflating: validation_set/IMG_1877_36.xml
#   inflating: validation_set/IMG_1877_38.JPG
#   inflating: validation_set/IMG_1877_38.xml
#   inflating: validation_set/IMG_1877_41.JPG
#   inflating: validation_set/IMG_1877_41.xml
#   inflating: validation_set/IMG_1878_01.JPG
#   inflating: validation_set/IMG_1878_01.xml
#   inflating: validation_set/IMG_1878_05.JPG
#   inflating: validation_set/IMG_1878_05.xml
#   inflating: validation_set/IMG_1878_11.JPG
#   inflating: validation_set/IMG_1878_11.xml
#   inflating: validation_set/IMG_1878_18.JPG
#   inflating: validation_set/IMG_1878_18.xml
#   inflating: validation_set/IMG_1878_23.JPG
#   inflating: validation_set/IMG_1878_23.xml
#   inflating: validation_set/IMG_1878_27.JPG
#   inflating: validation_set/IMG_1878_27.xml
#   inflating: validation_set/IMG_1878_34.JPG
#   inflating: validation_set/IMG_1878_34.xml
#   inflating: validation_set/IMG_1878_40.JPG
#   inflating: validation_set/IMG_1878_40.xml
#   inflating: validation_set/IMG_1878_41.JPG
#   inflating: validation_set/IMG_1878_41.xml
#   inflating: validation_set/IMG_1879_04.JPG
#   inflating: validation_set/IMG_1879_04.xml
#   inflating: validation_set/IMG_1879_05.JPG
#   inflating: validation_set/IMG_1879_05.xml
#   inflating: validation_set/IMG_1879_08.JPG
#   inflating: validation_set/IMG_1879_08.xml
#   inflating: validation_set/IMG_1879_09.JPG
#   inflating: validation_set/IMG_1879_09.xml
#   inflating: validation_set/IMG_1879_14.JPG
#   inflating: validation_set/IMG_1879_14.xml
#   inflating: validation_set/IMG_1879_21.JPG
#   inflating: validation_set/IMG_1879_21.xml
#   inflating: validation_set/IMG_1879_22.JPG
#   inflating: validation_set/IMG_1879_22.xml
#   inflating: validation_set/IMG_1879_24.JPG
#   inflating: validation_set/IMG_1879_24.xml
#   inflating: validation_set/IMG_1879_25.JPG
#   inflating: validation_set/IMG_1879_25.xml
#   inflating: validation_set/IMG_1879_26.JPG
#   inflating: validation_set/IMG_1879_26.xml
#   inflating: validation_set/IMG_1879_33.JPG
#   inflating: validation_set/IMG_1879_33.xml
#   inflating: validation_set/IMG_1879_35.JPG
#   inflating: validation_set/IMG_1879_35.xml
#   inflating: validation_set/IMG_1879_38.JPG
#   inflating: validation_set/IMG_1879_38.xml
#   inflating: validation_set/IMG_1879_40.JPG
#   inflating: validation_set/IMG_1879_40.xml
#   inflating: validation_set/IMG_1880_05.JPG
#   inflating: validation_set/IMG_1880_05.xml
#   inflating: validation_set/IMG_1880_15.JPG
#   inflating: validation_set/IMG_1880_15.xml
#   inflating: validation_set/IMG_1880_23.JPG
#   inflating: validation_set/IMG_1880_23.xml
#   inflating: validation_set/IMG_1880_26.JPG
#   inflating: validation_set/IMG_1880_26.xml
#   inflating: validation_set/IMG_1880_31.JPG
#   inflating: validation_set/IMG_1880_31.xml
#   inflating: validation_set/IMG_1880_33.JPG
#   inflating: validation_set/IMG_1880_33.xml
#   inflating: validation_set/IMG_1880_41.JPG
#   inflating: validation_set/IMG_1880_41.xml
#   inflating: validation_set/IMG_1881_07.JPG
#   inflating: validation_set/IMG_1881_07.xml
#   inflating: validation_set/IMG_1881_10.JPG
#   inflating: validation_set/IMG_1881_10.xml
#   inflating: validation_set/IMG_1881_12.JPG
#   inflating: validation_set/IMG_1881_12.xml
#   inflating: validation_set/IMG_1881_17.JPG
#   inflating: validation_set/IMG_1881_17.xml
#   inflating: validation_set/IMG_1881_19.JPG
#   inflating: validation_set/IMG_1881_19.xml
#   inflating: validation_set/IMG_1881_21.JPG
#   inflating: validation_set/IMG_1881_21.xml
#   inflating: validation_set/IMG_1881_24.JPG
#   inflating: validation_set/IMG_1881_24.xml
#   inflating: validation_set/IMG_1881_28.JPG
#   inflating: validation_set/IMG_1881_28.xml
#   inflating: validation_set/IMG_1881_31.JPG
#   inflating: validation_set/IMG_1881_31.xml
#   inflating: validation_set/IMG_1881_41.JPG
#   inflating: validation_set/IMG_1881_41.xml
#   inflating: validation_set/IMG_1882_09.JPG
#   inflating: validation_set/IMG_1882_09.xml
# ...
#   inflating: test_set/IMG_2786_11.JPG
#   inflating: test_set/IMG_2786_11.xml
#   inflating: test_set/IMG_2786_12.JPG
#   inflating: test_set/IMG_2786_12.xml
#   inflating: test_set/IMG_2786_13.JPG
#   inflating: test_set/IMG_2786_13.xml
#   inflating: test_set/IMG_2786_14.JPG
#   inflating: test_set/IMG_2786_14.xml
#   inflating: test_set/IMG_2786_15.JPG
#   inflating: test_set/IMG_2786_15.xml
#   inflating: test_set/IMG_2786_16.JPG
#   inflating: test_set/IMG_2786_16.xml
#   inflating: test_set/IMG_2786_17.JPG
#   inflating: test_set/IMG_2786_17.xml
#   inflating: test_set/IMG_2786_18.JPG
#   inflating: test_set/IMG_2786_18.xml
#   inflating: test_set/IMG_2786_19.JPG
#   inflating: test_set/IMG_2786_19.xml
#   inflating: test_set/IMG_2786_20.JPG
#   inflating: test_set/IMG_2786_20.xml
#   inflating: test_set/IMG_2786_21.JPG
#   inflating: test_set/IMG_2786_21.xml
#   inflating: test_set/IMG_2786_22.JPG
#   inflating: test_set/IMG_2786_22.xml
#   inflating: test_set/IMG_2786_23.JPG
#   inflating: test_set/IMG_2786_23.xml
#   inflating: test_set/IMG_2786_24.JPG
#   inflating: test_set/IMG_2786_24.xml
#   inflating: test_set/IMG_2786_25.JPG
#   inflating: test_set/IMG_2786_25.xml
#   inflating: test_set/IMG_2786_26.JPG
#   inflating: test_set/IMG_2786_26.xml
#   inflating: test_set/IMG_2786_27.JPG
#   inflating: test_set/IMG_2786_27.xml
#   inflating: test_set/IMG_2786_28.JPG
#   inflating: test_set/IMG_2786_28.xml
#   inflating: test_set/IMG_2786_29.JPG
#   inflating: test_set/IMG_2786_29.xml
#   inflating: test_set/IMG_2786_30.JPG
#   inflating: test_set/IMG_2786_30.xml
#   inflating: test_set/IMG_2786_31.JPG
#   inflating: test_set/IMG_2786_31.xml
#   inflating: test_set/IMG_2786_32.JPG
#   inflating: test_set/IMG_2786_32.xml
#   inflating: test_set/IMG_2786_33.JPG
#   inflating: test_set/IMG_2786_33.xml
#   inflating: test_set/IMG_2786_34.JPG
#   inflating: test_set/IMG_2786_34.xml
#   inflating: test_set/IMG_2786_35.JPG
#   inflating: test_set/IMG_2786_35.xml
#   inflating: test_set/IMG_2786_36.JPG
#   inflating: test_set/IMG_2786_36.xml
#   inflating: test_set/IMG_2786_37.JPG
#   inflating: test_set/IMG_2786_37.xml
#   inflating: test_set/IMG_2786_38.JPG
#   inflating: test_set/IMG_2786_38.xml
#   inflating: test_set/IMG_2786_39.JPG
#   inflating: test_set/IMG_2786_39.xml
#   inflating: test_set/IMG_2786_40.JPG
#   inflating: test_set/IMG_2786_40.xml
#   inflating: test_set/IMG_2786_41.JPG
#   inflating: test_set/IMG_2786_41.xml
#   inflating: test_set/IMG_2786_42.JPG
#   inflating: test_set/IMG_2786_42.xml
#   inflating: test_set/IMG_2787_01.JPG
#   inflating: test_set/IMG_2787_01.xml
#   inflating: test_set/IMG_2787_02.JPG
#   inflating: test_set/IMG_2787_02.xml
#   inflating: test_set/IMG_2787_03.JPG
#   inflating: test_set/IMG_2787_03.xml
#   inflating: test_set/IMG_2787_04.JPG
#   inflating: test_set/IMG_2787_04.xml
#   inflating: test_set/IMG_2787_05.JPG
#   inflating: test_set/IMG_2787_05.xml
#   inflating: test_set/IMG_2787_06.JPG
#   inflating: test_set/IMG_2787_06.xml
#   inflating: test_set/IMG_2787_07.JPG
#   inflating: test_set/IMG_2787_07.xml
#   inflating: test_set/IMG_2787_08.JPG
#   inflating: test_set/IMG_2787_08.xml
#   inflating: test_set/IMG_2787_09.JPG
#   inflating: test_set/IMG_2787_09.xml
#   inflating: test_set/IMG_2787_10.JPG
#   inflating: test_set/IMG_2787_10.xml
#   inflating: test_set/IMG_2787_11.JPG
#   inflating: test_set/IMG_2787_11.xml
#   inflating: test_set/IMG_2787_12.JPG
#   inflating: test_set/IMG_2787_12.xml
#   inflating: test_set/IMG_2787_13.JPG
#   inflating: test_set/IMG_2787_13.xml
#   inflating: test_set/IMG_2787_14.JPG
#   inflating: test_set/IMG_2787_14.xml
#   inflating: test_set/IMG_2787_15.JPG
#   inflating: test_set/IMG_2787_15.xml
#   inflating: test_set/IMG_2787_16.JPG
#   inflating: test_set/IMG_2787_16.xml
#   inflating: test_set/IMG_2787_17.JPG
#   inflating: test_set/IMG_2787_17.xml
#   inflating: test_set/IMG_2787_18.JPG
#   inflating: test_set/IMG_2787_18.xml
#   inflating: test_set/IMG_2787_19.JPG
#   inflating: test_set/IMG_2787_19.xml
#   inflating: test_set/IMG_2787_20.JPG
#   inflating: test_set/IMG_2787_20.xml
#   inflating: test_set/IMG_2787_21.JPG
#   inflating: test_set/IMG_2787_21.xml
#   inflating: test_set/IMG_2787_22.JPG
#   inflating: test_set/IMG_2787_22.xml
#   inflating: test_set/IMG_2787_23.JPG
#   inflating: test_set/IMG_2787_23.xml
#   inflating: test_set/IMG_2787_24.JPG
#   inflating: test_set/IMG_2787_24.xml
#   inflating: test_set/IMG_2787_25.JPG
#   inflating: test_set/IMG_2787_25.xml
#   inflating: test_set/IMG_2787_26.JPG
#   inflating: test_set/IMG_2787_26.xml
#   inflating: test_set/IMG_2787_27.JPG
#   inflating: test_set/IMG_2787_27.xml
#   inflating: test_set/IMG_2787_28.JPG
#   inflating: test_set/IMG_2787_28.xml
#   inflating: test_set/IMG_2787_29.JPG
#   inflating: test_set/IMG_2787_29.xml
#   inflating: test_set/IMG_2787_30.JPG
#   inflating: test_set/IMG_2787_30.xml
#   inflating: test_set/IMG_2787_31.JPG
#   inflating: test_set/IMG_2787_31.xml
#   inflating: test_set/IMG_2787_32.JPG
#   inflating: test_set/IMG_2787_32.xml
#   inflating: test_set/IMG_2787_33.JPG
#   inflating: test_set/IMG_2787_33.xml
#   inflating: test_set/IMG_2787_34.JPG
#   inflating: test_set/IMG_2787_34.xml
#   inflating: test_set/IMG_2787_35.JPG
#   inflating: test_set/IMG_2787_35.xml
#   inflating: test_set/IMG_2787_36.JPG
#   inflating: test_set/IMG_2787_36.xml
#   inflating: test_set/IMG_2787_37.JPG
#   inflating: test_set/IMG_2787_37.xml
#   inflating: test_set/IMG_2787_38.JPG
#   inflating: test_set/IMG_2787_38.xml
#   inflating: test_set/IMG_2787_39.JPG
#   inflating: test_set/IMG_2787_39.xml
#   inflating: test_set/IMG_2787_40.JPG
#   inflating: test_set/IMG_2787_40.xml
#   inflating: test_set/IMG_2787_41.JPG
#   inflating: test_set/IMG_2787_41.xml
#   inflating: test_set/IMG_2787_42.JPG
#   inflating: test_set/IMG_2787_42.xml
#   inflating: test_set/IMG_2788_01.JPG
#   inflating: test_set/IMG_2788_01.xml
#   inflating: test_set/IMG_2788_02.JPG
#   inflating: test_set/IMG_2788_02.xml
#   inflating: test_set/IMG_2788_03.JPG
#   inflating: test_set/IMG_2788_03.xml
#   inflating: test_set/IMG_2788_04.JPG
#   inflating: test_set/IMG_2788_04.xml
#   inflating: test_set/IMG_2788_05.JPG
#   inflating: test_set/IMG_2788_05.xml
#   inflating: test_set/IMG_2788_06.JPG
#   inflating: test_set/IMG_2788_06.xml
#   inflating: test_set/IMG_2788_07.JPG
#   inflating: test_set/IMG_2788_07.xml
#   inflating: test_set/IMG_2788_08.JPG
#   inflating: test_set/IMG_2788_08.xml
#   inflating: test_set/IMG_2788_09.JPG
#   inflating: test_set/IMG_2788_09.xml
#   inflating: test_set/IMG_2788_10.JPG
#   inflating: test_set/IMG_2788_10.xml
#   inflating: test_set/IMG_2788_11.JPG
#   inflating: test_set/IMG_2788_11.xml
#   inflating: test_set/IMG_2788_12.JPG
#   inflating: test_set/IMG_2788_12.xml
#   inflating: test_set/IMG_2788_13.JPG
#   inflating: test_set/IMG_2788_13.xml
#   inflating: test_set/IMG_2788_14.JPG
#   inflating: test_set/IMG_2788_14.xml
#   inflating: test_set/IMG_2788_15.JPG
#   inflating: test_set/IMG_2788_15.xml
#   inflating: test_set/IMG_2788_16.JPG
#   inflating: test_set/IMG_2788_16.xml
#   inflating: test_set/IMG_2788_17.JPG
#   inflating: test_set/IMG_2788_17.xml
#   inflating: test_set/IMG_2788_18.JPG
#   inflating: test_set/IMG_2788_18.xml
#   inflating: test_set/IMG_2788_19.JPG
#   inflating: test_set/IMG_2788_19.xml
#   inflating: test_set/IMG_2788_20.JPG
#   inflating: test_set/IMG_2788_20.xml
#   inflating: test_set/IMG_2788_21.JPG
#   inflating: test_set/IMG_2788_21.xml
#   inflating: test_set/IMG_2788_22.JPG
#   inflating: test_set/IMG_2788_22.xml
#   inflating: test_set/IMG_2788_23.JPG
#   inflating: test_set/IMG_2788_23.xml
#   inflating: test_set/IMG_2788_24.JPG
#   inflating: test_set/IMG_2788_24.xml
#   inflating: test_set/IMG_2788_25.JPG
#   inflating: test_set/IMG_2788_25.xml
#   inflating: test_set/IMG_2788_26.JPG
#   inflating: test_set/IMG_2788_26.xml
#   inflating: test_set/IMG_2788_27.JPG
#   inflating: test_set/IMG_2788_27.xml
#   inflating: test_set/IMG_2788_28.JPG
#   inflating: test_set/IMG_2788_28.xml
#   inflating: test_set/IMG_2788_29.JPG
#   inflating: test_set/IMG_2788_29.xml
#   inflating: test_set/IMG_2788_30.JPG
#   inflating: test_set/IMG_2788_30.xml
#   inflating: test_set/IMG_2788_31.JPG
#   inflating: test_set/IMG_2788_31.xml
#   inflating: test_set/IMG_2788_32.JPG
#   inflating: test_set/IMG_2788_32.xml
#   inflating: test_set/IMG_2788_33.JPG
#   inflating: test_set/IMG_2788_33.xml
#   inflating: test_set/IMG_2788_34.JPG
#   inflating: test_set/IMG_2788_34.xml
#   inflating: test_set/IMG_2788_35.JPG
#   inflating: test_set/IMG_2788_35.xml
#   inflating: test_set/IMG_2788_36.JPG
#   inflating: test_set/IMG_2788_36.xml
#   inflating: test_set/IMG_2788_37.JPG
#   inflating: test_set/IMG_2788_37.xml
#   inflating: test_set/IMG_2788_38.JPG
#   inflating: test_set/IMG_2788_38.xml
#   inflating: test_set/IMG_2788_39.JPG
#   inflating: test_set/IMG_2788_39.xml
#   inflating: test_set/IMG_2788_40.JPG
#   inflating: test_set/IMG_2788_40.xml
#   inflating: test_set/IMG_2788_41.JPG
#   inflating: test_set/IMG_2788_41.xml
#   inflating: test_set/IMG_2788_42.JPG
#   inflating: test_set/IMG_2788_42.xml
#   inflating: test_set/IMG_2806_01.JPG
#   inflating: test_set/IMG_2806_01.xml
#   inflating: test_set/IMG_2806_02.JPG
#   inflating: test_set/IMG_2806_02.xml
#   inflating: test_set/IMG_2806_03.JPG
#   inflating: test_set/IMG_2806_03.xml
#   inflating: test_set/IMG_2806_04.JPG
#   inflating: test_set/IMG_2806_04.xml
#   inflating: test_set/IMG_2806_05.JPG
#   inflating: test_set/IMG_2806_05.xml
#   inflating: test_set/IMG_2806_06.JPG
#   inflating: test_set/IMG_2806_06.xml
#   inflating: test_set/IMG_2806_07.JPG
#   inflating: test_set/IMG_2806_07.xml
#   inflating: test_set/IMG_2806_08.JPG
#   inflating: test_set/IMG_2806_08.xml
#   inflating: test_set/IMG_2806_09.JPG
#   inflating: test_set/IMG_2806_09.xml
#   inflating: test_set/IMG_2806_10.JPG
#   inflating: test_set/IMG_2806_10.xml
#   inflating: test_set/IMG_2806_11.JPG
#   inflating: test_set/IMG_2806_11.xml
#   inflating: test_set/IMG_2806_12.JPG
#   inflating: test_set/IMG_2806_12.xml
#   inflating: test_set/IMG_2806_13.JPG
#   inflating: test_set/IMG_2806_13.xml
#   inflating: test_set/IMG_2806_14.JPG
#   inflating: test_set/IMG_2806_14.xml
#   inflating: test_set/IMG_2806_15.JPG
#   inflating: test_set/IMG_2806_15.xml
#   inflating: test_set/IMG_2806_16.JPG
#   inflating: test_set/IMG_2806_16.xml
#   inflating: test_set/IMG_2806_17.JPG
#   inflating: test_set/IMG_2806_17.xml
#   inflating: test_set/IMG_2806_18.JPG
#   inflating: test_set/IMG_2806_18.xml
#   inflating: test_set/IMG_2806_19.JPG
#   inflating: test_set/IMG_2806_19.xml
#   inflating: test_set/IMG_2806_20.JPG
#   inflating: test_set/IMG_2806_20.xml
#   inflating: test_set/IMG_2806_21.JPG
#   inflating: test_set/IMG_2806_21.xml
#   inflating: test_set/IMG_2806_22.JPG
#   inflating: test_set/IMG_2806_22.xml
#   inflating: test_set/IMG_2806_23.JPG
#   inflating: test_set/IMG_2806_23.xml
#   inflating: test_set/IMG_2806_24.JPG
#   inflating: test_set/IMG_2806_24.xml
#   inflating: test_set/IMG_2806_25.JPG
#   inflating: test_set/IMG_2806_25.xml
#   inflating: test_set/IMG_2806_26.JPG
#   inflating: test_set/IMG_2806_26.xml
#   inflating: test_set/IMG_2806_27.JPG
#   inflating: test_set/IMG_2806_27.xml
#   inflating: test_set/IMG_2806_28.JPG
#   inflating: test_set/IMG_2806_28.xml
#   inflating: test_set/IMG_2806_29.JPG
#   inflating: test_set/IMG_2806_29.xml
#   inflating: test_set/IMG_2806_30.JPG
#   inflating: test_set/IMG_2806_30.xml
#   inflating: test_set/IMG_2806_31.JPG
#   inflating: test_set/IMG_2806_31.xml
#   inflating: test_set/IMG_2806_32.JPG
#   inflating: test_set/IMG_2806_32.xml
#   inflating: test_set/IMG_2806_33.JPG
#   inflating: test_set/IMG_2806_33.xml
#   inflating: test_set/IMG_2806_34.JPG
#   inflating: test_set/IMG_2806_34.xml
#   inflating: test_set/IMG_2806_35.JPG
#   inflating: test_set/IMG_2806_35.xml
#   inflating: test_set/IMG_2806_36.JPG
#   inflating: test_set/IMG_2806_36.xml
#   inflating: test_set/IMG_2806_37.JPG
#   inflating: test_set/IMG_2806_37.xml
#   inflating: test_set/IMG_2806_38.JPG
#   inflating: test_set/IMG_2806_38.xml
#   inflating: test_set/IMG_2806_39.JPG
#   inflating: test_set/IMG_2806_39.xml
#   inflating: test_set/IMG_2806_40.JPG
#   inflating: test_set/IMG_2806_40.xml
#   inflating: test_set/IMG_2806_41.JPG
#   inflating: test_set/IMG_2806_41.xml
#   inflating: test_set/IMG_2806_42.JPG
#   inflating: test_set/IMG_2806_42.xml
#   inflating: test_set/IMG_2885_01.JPG
#   inflating: test_set/IMG_2885_01.xml
#   inflating: test_set/IMG_2885_02.JPG
#   inflating: test_set/IMG_2885_02.xml
#   inflating: test_set/IMG_2885_03.JPG
#   inflating: test_set/IMG_2885_03.xml
#   inflating: test_set/IMG_2885_04.JPG
#   inflating: test_set/IMG_2885_04.xml
#   inflating: test_set/IMG_2885_05.JPG
#   inflating: test_set/IMG_2885_05.xml
#   inflating: test_set/IMG_2885_06.JPG
#   inflating: test_set/IMG_2885_06.xml
#   inflating: test_set/IMG_2885_07.JPG
#   inflating: test_set/IMG_2885_07.xml
#   inflating: test_set/IMG_2885_08.JPG
#   inflating: test_set/IMG_2885_08.xml
#   inflating: test_set/IMG_2885_09.JPG
#   inflating: test_set/IMG_2885_09.xml
#   inflating: test_set/IMG_2885_10.JPG
#   inflating: test_set/IMG_2885_10.xml
#   inflating: test_set/IMG_2885_11.JPG
#   inflating: test_set/IMG_2885_11.xml
#   inflating: test_set/IMG_2885_12.JPG
#   inflating: test_set/IMG_2885_12.xml
#   inflating: test_set/IMG_2885_13.JPG
#   inflating: test_set/IMG_2885_13.xml
#   inflating: test_set/IMG_2885_14.JPG
#   inflating: test_set/IMG_2885_14.xml
#   inflating: test_set/IMG_2885_15.JPG
#   inflating: test_set/IMG_2885_15.xml
#   inflating: test_set/IMG_2885_16.JPG
#   inflating: test_set/IMG_2885_16.xml
#   inflating: test_set/IMG_2885_17.JPG
#   inflating: test_set/IMG_2885_17.xml
#   inflating: test_set/IMG_2885_18.JPG
#   inflating: test_set/IMG_2885_18.xml
#   inflating: test_set/IMG_2885_19.JPG
#   inflating: test_set/IMG_2885_19.xml
#   inflating: test_set/IMG_2885_20.JPG
#   inflating: test_set/IMG_2885_20.xml
#   inflating: test_set/IMG_2885_21.JPG
#   inflating: test_set/IMG_2885_21.xml
#   inflating: test_set/IMG_2885_22.JPG
#   inflating: test_set/IMG_2885_22.xml
#   inflating: test_set/IMG_2885_23.JPG
#   inflating: test_set/IMG_2885_23.xml
#   inflating: test_set/IMG_2885_24.JPG
#   inflating: test_set/IMG_2885_24.xml
#   inflating: test_set/IMG_2885_25.JPG
#   inflating: test_set/IMG_2885_25.xml
#   inflating: test_set/IMG_2885_26.JPG
#   inflating: test_set/IMG_2885_26.xml
#   inflating: test_set/IMG_2885_27.JPG
#   inflating: test_set/IMG_2885_27.xml
#   inflating: test_set/IMG_2885_28.JPG
#   inflating: test_set/IMG_2885_28.xml
#   inflating: test_set/IMG_2885_29.JPG
#   inflating: test_set/IMG_2885_29.xml
#   inflating: test_set/IMG_2885_30.JPG
#   inflating: test_set/IMG_2885_30.xml
#   inflating: test_set/IMG_2885_31.JPG
#   inflating: test_set/IMG_2885_31.xml
#   inflating: test_set/IMG_2885_32.JPG
#   inflating: test_set/IMG_2885_32.xml
#   inflating: test_set/IMG_2885_33.JPG
#   inflating: test_set/IMG_2885_33.xml
#   inflating: test_set/IMG_2885_34.JPG
#   inflating: test_set/IMG_2885_34.xml
#   inflating: test_set/IMG_2885_35.JPG
#   inflating: test_set/IMG_2885_35.xml
#   inflating: test_set/IMG_2885_36.JPG
#   inflating: test_set/IMG_2885_36.xml
#   inflating: test_set/IMG_2885_37.JPG
#   inflating: test_set/IMG_2885_37.xml
#   inflating: test_set/IMG_2885_38.JPG
#   inflating: test_set/IMG_2885_38.xml
#   inflating: test_set/IMG_2885_39.JPG
#   inflating: test_set/IMG_2885_39.xml
#   inflating: test_set/IMG_2885_40.JPG
#   inflating: test_set/IMG_2885_40.xml
#   inflating: test_set/IMG_2885_41.JPG
#   inflating: test_set/IMG_2885_41.xml
#   inflating: test_set/IMG_2885_42.JPG
#   inflating: test_set/IMG_2885_42.xml

# %%
# !pip install -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate user
auth.authenticate_user()

gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()

drive = GoogleDrive(gauth)

print("✅ Google Drive authentication successful")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.4/987.4 kB 9.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
#   Building wheel for PyDrive (setup.py) ... done
# ^C
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_55/3524020800.py in <cell line: 0>()
#       1 get_ipython().system('pip install -q PyDrive')
#       2
# ----> 3 from pydrive.auth import GoogleAuth
#       4 from pydrive.drive import GoogleDrive
#       5 from google.colab import auth
#
# ModuleNotFoundError: No module named 'pydrive'

# %%
import os
import xml.etree.ElementTree as ET
from pathlib import Path
from collections import Counter

# Root from your screenshot
data_root = Path("/kaggle/working")

CLASS_NAMES = [
    "CYPRO","CYPRO_max","CYPRO_min","ECHCG","ECHCG_V1","ECHCG_V2",
    "ECHCG_Ve","NC","OE","POROL","SOLNI","SOLNI_V1","SOLNI_V2",
    "SOLNI_Vc","ZEAMX","ZEAMX_V1","ZEAMX_V3","ZEAMX_V4"
]

def count_xml_labels(folder_path):
    counts = Counter()
    # Find all XML files in the folder (including subfolders just in case)
    xml_files = list(folder_path.rglob("*.xml"))

    for xml_file in xml_files:
        try:
            tree = ET.parse(xml_file)
            root = tree.getroot()

            # Find every <object> tag in the XML
            for obj in root.findall('object'):
                name = obj.find('name').text
                if name in CLASS_NAMES:
                    counts[name] += 1
                else:
                    # In case there's a typo in the XML names vs your list
                    counts[name] += 1
        except Exception as e:
            continue # Skip corrupted files
    return counts

# Mapping based on your screenshot
splits = {
    "Train": data_root / "train_set",
    "Val":   data_root / "validation_set",
    "Test":  data_root / "test_set"
}

# Run the counter
results = {split_name: count_xml_labels(path) for split_name, path in splits.items()}

# Print Results
header = f"{'Class':<15} {'Train':>8} {'Val':>8} {'Test':>8}"
print(header)
print("-" * len(header))

for name in CLASS_NAMES:
    t = results["Train"].get(name, 0)
    v = results["Val"].get(name, 0)
    te = results["Test"].get(name, 0)
    print(f"{name:<15} {t:>8} {v:>8} {te:>8}")
# Out:
# Class              Train      Val     Test
# ------------------------------------------
# CYPRO               6726     1977     3399
# CYPRO_max           9183     2764     4860
# CYPRO_min           7737     2385     4063
# ECHCG               3160     1080     1293
# ECHCG_V1               0        0       19
# ECHCG_V2               0        0      205
# ECHCG_Ve            2998      861     1545
# NC                  6178     1912     3125
# OE                     0        0       15
# POROL                  0        0        5
# SOLNI                  0        0        1
# SOLNI_V1            4890     1614     2267
# SOLNI_V2               0        0        2
# SOLNI_Vc            7762     2288     3852
# ZEAMX                 89       23       57
# ZEAMX_V1           13014     3853     6309
# ZEAMX_V3            4515     1310     2228
# ZEAMX_V4            1522      483      746

# %% [markdown]
# ## MAIN

# %%
"""
WeedMaize — Robust Multi-Label Stratified Dataset Splitter
===========================================================
Problem solved:
  - Dominant-label stratification ignores minority classes inside images
  - Pre-split folders carry historical bias
  - Rare classes randomly fall into only train or only test

Solution:
  - Iterative multi-label stratification (Sechidis et al., 2011)
    via skmultilearn — every class in every image is balanced
  - Fallback: guaranteed seeding of rare classes into ALL splits
    before stratification runs
  - Class weights computed and exported for use in your loss function
"""

import os
import shutil
import json
import xml.etree.ElementTree as ET
from pathlib import Path
from collections import Counter, defaultdict
import numpy as np

# ── Optional imports (graceful fallback) ────────────────────────────────────
try:
    from skmultilearn.model_selection import IterativeStratification
    HAS_SKMULTILEARN = True
except ImportError:
    HAS_SKMULTILEARN = False
    print("⚠️  skmultilearn not found — using fallback multi-label stratifier.")
    print("    Install with: pip install scikit-multilearn")

# ═══════════════════════════════════════════════════════════════════════════
# 1. CONFIGURATION
# ═══════════════════════════════════════════════════════════════════════════

ROOT       = Path("/kaggle/working")          # train_set / val_set / test_set live here
NEW_ROOT   = Path("/kaggle/working/stratified_dataset")  # output goes here

# Split ratios — must sum to 1.0
TRAIN_RATIO = 0.80
VAL_RATIO   = 0.10
TEST_RATIO  = 0.10

RANDOM_SEED = 42

# Minimum samples a class must have in EACH split after stratification.
# Images containing only ultra-rare classes are force-seeded first.
MIN_PER_SPLIT = 5

# ── Label merge map ─────────────────────────────────────────────────────────
# Classes absent from this map are DROPPED silently.
LABEL_MAP = {
    "CYPRO":     "CYPRO",
    "CYPRO_max": "CYPRO_max",
    "CYPRO_min": "CYPRO_min",

    "ECHCG":    "ECHCG",
    "ECHCG_V1": "ECHCG_Ve",   # merge V1 + V2 into Ve
    "ECHCG_V2": "ECHCG_Ve",
    "ECHCG_Ve": "ECHCG_Ve",

    "NC": "NC",

    "SOLNI":    "SOLNI_V1",   # merge base + V1 + V2
    "SOLNI_V1": "SOLNI_V1",
    "SOLNI_V2": "SOLNI_V1",
    "SOLNI_Vc": "SOLNI_Vc",   # keep separate — very numerous

    "ZEAMX":    "ZEAMX_V1",   # merge base into V1
    "ZEAMX_V1": "ZEAMX_V1",
    "ZEAMX_V3": "ZEAMX_V3",
    "ZEAMX_V4": "ZEAMX_V4",

    # OE, POROL — intentionally excluded
}

FINAL_CLASSES = sorted(set(LABEL_MAP.values()))
CLS_TO_IDX    = {c: i for i, c in enumerate(FINAL_CLASSES)}
N_CLASSES     = len(FINAL_CLASSES)


# ═══════════════════════════════════════════════════════════════════════════
# 2. COLLECT ALL IMAGE-ANNOTATION PAIRS
# ═══════════════════════════════════════════════════════════════════════════

def collect_all_pairs() -> list[dict]:
    """Scan all three original folders, parse XML, map labels."""
    all_data, skipped = [], 0
    print("\n── Scanning original dataset folders ──────────────────────────────")

    for folder in ["train_set", "validation_set", "test_set"]:
        folder_path = ROOT / folder
        if not folder_path.exists():
            print(f"  ⚠️  Not found, skipping: {folder_path}")
            continue

        xmls = sorted(folder_path.glob("*.xml"))
        print(f"  {folder}: {len(xmls)} XML files found")

        for xml_file in xmls:
            img_file = xml_file.with_suffix(".jpg")
            if not img_file.exists():
                img_file = xml_file.with_suffix(".JPG")
            if not img_file.exists():
                skipped += 1
                continue

            try:
                tree    = ET.parse(xml_file)
                root_el = tree.getroot()

                # All mapped labels in this image (one per bounding box)
                mapped = [
                    LABEL_MAP[obj.find("name").text]
                    for obj in root_el.findall("object")
                    if obj.find("name") is not None
                    and obj.find("name").text in LABEL_MAP
                ]
                if not mapped:
                    skipped += 1
                    continue

                # Multi-hot vector — presence of each class in this image
                multi_hot = np.zeros(N_CLASSES, dtype=np.int8)
                for lbl in mapped:
                    multi_hot[CLS_TO_IDX[lbl]] = 1

                # Box-level counts per class (used for class weights later)
                box_counts = Counter(mapped)

                all_data.append({
                    "xml":       xml_file,
                    "img":       img_file,
                    "stem":      f"{folder}__{xml_file.stem}",
                    "multi_hot": multi_hot,          # shape (N_CLASSES,)
                    "box_counts": box_counts,
                })

            except Exception as e:
                print(f"  ⚠️  Parse error {xml_file.name}: {e}")
                skipped += 1

    print(f"\n✅  Collected {len(all_data)} valid pairs. Skipped {skipped}.")
    return all_data


# ═══════════════════════════════════════════════════════════════════════════
# 3. PRINT CLASS DISTRIBUTION
# ═══════════════════════════════════════════════════════════════════════════

def print_distribution(all_data: list[dict], title: str = "Full dataset"):
    """Show image-level and box-level counts per class."""
    img_counts = Counter()
    box_counts  = Counter()
    for d in all_data:
        for cls, idx in CLS_TO_IDX.items():
            if d["multi_hot"][idx]:
                img_counts[cls] += 1
        for cls, cnt in d["box_counts"].items():
            box_counts[cls] += cnt

    total_imgs = len(all_data)
    total_boxes = sum(box_counts.values())

    print(f"\n{'─'*70}")
    print(f"  {title}  ({total_imgs} images | {total_boxes} bounding boxes)")
    print(f"{'─'*70}")
    print(f"  {'Class':<15} {'Images':>8} {'Img%':>7}  {'Boxes':>8} {'Box%':>7}")
    print(f"  {'─'*15} {'─'*8} {'─'*7}  {'─'*8} {'─'*7}")
    for cls in FINAL_CLASSES:
        ic = img_counts.get(cls, 0)
        bc = box_counts.get(cls, 0)
        flag = "  ⚠️ RARE" if ic < MIN_PER_SPLIT * 3 else ""
        print(f"  {cls:<15} {ic:>8} {ic/total_imgs*100:>6.1f}%  "
              f"{bc:>8} {bc/total_boxes*100:>6.1f}%{flag}")
    print(f"{'─'*70}")
    return img_counts, box_counts


# ═══════════════════════════════════════════════════════════════════════════
# 4. RARE-CLASS FORCE SEEDING
# ═══════════════════════════════════════════════════════════════════════════

def force_seed_rare_classes(
    all_data: list[dict],
    img_counts: Counter,
) -> tuple[list[int], list[int], list[int], list[int]]:
    """
    For any class with fewer than MIN_PER_SPLIT * 3 images, guarantee
    at least MIN_PER_SPLIT samples land in each split by reserving them
    before stratification runs.

    Returns: (train_seed, val_seed, test_seed, remaining_indices)
    """
    rare_classes = [
        cls for cls in FINAL_CLASSES
        if img_counts.get(cls, 0) < MIN_PER_SPLIT * 3
    ]

    if not rare_classes:
        print("\n✅  No rare classes detected — skipping force-seed step.")
        return [], [], [], list(range(len(all_data)))

    print(f"\n⚠️  Rare classes detected (< {MIN_PER_SPLIT * 3} images): {rare_classes}")
    print("    Force-seeding these across all splits before stratification...")

    train_seed, val_seed, test_seed = [], [], []
    seeded = set()

    for cls in rare_classes:
        cls_idx = CLS_TO_IDX[cls]
        # Indices of images that contain this rare class
        candidates = [
            i for i, d in enumerate(all_data)
            if d["multi_hot"][cls_idx] and i not in seeded
        ]
        np.random.shuffle(candidates)  # reproducible via seed set before call

        n = len(candidates)
        # Proportional seeding respecting ratios
        n_train = max(MIN_PER_SPLIT, round(n * TRAIN_RATIO))
        n_val   = max(1, round(n * VAL_RATIO))
        n_test  = max(1, n - n_train - n_val)
        # Clip if not enough
        n_train = min(n_train, n - 2)
        n_val   = min(n_val,   n - n_train - 1)
        n_test  = n - n_train - n_val

        for i in candidates[:n_train]:
            train_seed.append(i); seeded.add(i)
        for i in candidates[n_train:n_train + n_val]:
            val_seed.append(i);   seeded.add(i)
        for i in candidates[n_train + n_val:n_train + n_val + n_test]:
            test_seed.append(i);  seeded.add(i)

        actual_seeded = candidates[:n_train + n_val + n_test]
        print(f"    {cls}: seeded {n_train} train | {n_val} val | {n_test} test "
              f"(of {n} total)")

    remaining = [i for i in range(len(all_data)) if i not in seeded]
    print(f"\n  Seeded {len(seeded)} images. {len(remaining)} remain for stratification.")
    return train_seed, val_seed, test_seed, remaining


# ═══════════════════════════════════════════════════════════════════════════
# 5A. ITERATIVE MULTI-LABEL STRATIFICATION (preferred)
# ═══════════════════════════════════════════════════════════════════════════

def iterative_stratify(
    indices: list[int],
    all_data: list[dict],
) -> tuple[list[int], list[int], list[int]]:
    """Use skmultilearn IterativeStratification on remaining pool."""
    X = np.array(indices).reshape(-1, 1)
    Y = np.vstack([all_data[i]["multi_hot"] for i in indices])

    # Two-step: split off test, then split remainder into train/val
    test_size  = TEST_RATIO / (TRAIN_RATIO + VAL_RATIO + TEST_RATIO)
    val_size_2 = VAL_RATIO  / (TRAIN_RATIO + VAL_RATIO)

    # Pre-shuffle for reproducibility — IterativeStratification does not
    # accept random_state when shuffle=False (its only supported mode)
    rng = np.random.default_rng(RANDOM_SEED)
    perm = rng.permutation(len(indices))
    X, Y = X[perm], Y[perm]

    strat1 = IterativeStratification(
        n_splits=2,
        order=2,
        sample_distribution_per_fold=[test_size, 1 - test_size],
    )
    for train_val_pos, test_pos in strat1.split(X, Y):
        break  # only need first fold

    X_tv, Y_tv = X[train_val_pos], Y[train_val_pos]

    strat2 = IterativeStratification(
        n_splits=2,
        order=2,
        sample_distribution_per_fold=[val_size_2, 1 - val_size_2],
    )
    for train_pos, val_pos in strat2.split(X_tv, Y_tv):
        break

    train_idx = [X_tv[i, 0] for i in train_pos]
    val_idx   = [X_tv[i, 0] for i in val_pos]
    test_idx  = [X[i, 0] for i in test_pos]

    return train_idx, val_idx, test_idx


# ═══════════════════════════════════════════════════════════════════════════
# 5B. FALLBACK: GREEDY MULTI-LABEL STRATIFICATION
# ═══════════════════════════════════════════════════════════════════════════

def greedy_multilabel_stratify(
    indices: list[int],
    all_data: list[dict],
) -> tuple[list[int], list[int], list[int]]:
    """
    Greedy fallback when skmultilearn is unavailable.
    Assigns each image to the split where its rarest class is most under-represented.
    Substantially better than dominant-label single-label stratification.
    """
    rng = np.random.default_rng(RANDOM_SEED)
    idx_arr = np.array(indices)
    rng.shuffle(idx_arr)

    # Track how many images of each class are in each split
    cls_counts = {
        "train": np.zeros(N_CLASSES, dtype=int),
        "val":   np.zeros(N_CLASSES, dtype=int),
        "test":  np.zeros(N_CLASSES, dtype=int),
    }
    split_total = {"train": 0, "val": 0, "test": 0}
    split_map   = {"train": [], "val": [], "test": []}

    target = {
        "train": TRAIN_RATIO,
        "val":   VAL_RATIO,
        "test":  TEST_RATIO,
    }
    n_total = len(idx_arr)

    for i in idx_arr:
        hot    = all_data[i]["multi_hot"]
        active = np.where(hot)[0]   # classes present in this image

        best_split, best_score = None, float("inf")
        for split_name in ["train", "val", "test"]:
            # Penalise if this split is already over its target ratio
            size_penalty = split_total[split_name] / max(n_total * target[split_name], 1)

            # For each active class, compute how under-represented it is here
            deficit = 0.0
            for ci in active:
                total_of_cls = sum(cls_counts[s][ci] for s in ["train", "val", "test"])
                if total_of_cls == 0:
                    deficit += 1.0   # unseen class — high priority
                else:
                    expected = target[split_name] * total_of_cls
                    actual   = cls_counts[split_name][ci]
                    deficit += max(0.0, expected - actual) / total_of_cls

            # Lower score = better (more deficit, less size penalty)
            score = size_penalty - deficit / max(len(active), 1)

            if score < best_score:
                best_score, best_split = score, split_name

        split_map[best_split].append(i)
        split_total[best_split] += 1
        for ci in active:
            cls_counts[best_split][ci] += 1

    return split_map["train"], split_map["val"], split_map["test"]


# ═══════════════════════════════════════════════════════════════════════════
# 6. COMPUTE CLASS WEIGHTS (for loss balancing during training)
# ═══════════════════════════════════════════════════════════════════════════

def compute_class_weights(train_indices: list[int], all_data: list[dict]) -> dict:
    """
    Inverse-frequency weights on BOUNDING BOX counts in the training set.
    Export as JSON for direct use in your training script.
    """
    box_counts = Counter()
    for i in train_indices:
        for cls, cnt in all_data[i]["box_counts"].items():
            box_counts[cls] += cnt

    total = sum(box_counts.values())
    n_cls = len(FINAL_CLASSES)

    # Balanced inverse-frequency: w_i = total / (n_classes * count_i)
    weights = {}
    for cls in FINAL_CLASSES:
        cnt = box_counts.get(cls, 0)
        if cnt == 0:
            weights[cls] = 0.0   # shouldn't happen after seeding
        else:
            weights[cls] = round(total / (n_cls * cnt), 4)

    return weights


# ═══════════════════════════════════════════════════════════════════════════
# 7. COPY / SYMLINK FILES
# ═══════════════════════════════════════════════════════════════════════════

def create_split_files(
    indices: list[int],
    all_data: list[dict],
    split_name: str,
    use_symlinks: bool = True,
):
    """Write image + XML into split folder (symlink or hard copy)."""
    dest = NEW_ROOT / split_name
    dest.mkdir(parents=True, exist_ok=True)

    for i in indices:
        item = all_data[i]
        xml_dst = dest / f"{item['stem']}.xml"
        img_dst = dest / f"{item['stem']}{item['img'].suffix}"

        for src, dst in [(item["xml"], xml_dst), (item["img"], img_dst)]:
            if dst.exists() or dst.is_symlink():
                dst.unlink()
            if use_symlinks:
                os.symlink(src.resolve(), dst)
            else:
                shutil.copy2(src, dst)

    print(f"  ✅ {split_name:<6}: {len(indices)} images → {dest}")


# ═══════════════════════════════════════════════════════════════════════════
# 8. SPLIT VALIDATION — catch mismatches BEFORE training
# ═══════════════════════════════════════════════════════════════════════════

def validate_splits(
    train_idx: list[int],
    val_idx:   list[int],
    test_idx:  list[int],
    all_data:  list[dict],
) -> bool:
    """
    Assert:
      1. No image appears in more than one split
      2. Every class present in test/val also exists in train
      3. No split has 0 images of any class that exists in the full dataset
    """
    print("\n── Validating splits ───────────────────────────────────────────────")
    ok = True

    # (1) Overlap check
    sets = [set(train_idx), set(val_idx), set(test_idx)]
    for a, b, name in [(sets[0], sets[1], "train∩val"),
                       (sets[0], sets[2], "train∩test"),
                       (sets[1], sets[2], "val∩test")]:
        overlap = a & b
        if overlap:
            print(f"  ❌ OVERLAP in {name}: {len(overlap)} images shared!")
            ok = False
        else:
            print(f"  ✅ No overlap: {name}")

    # (2 & 3) Class coverage
    def cls_set(idxs):
        s = set()
        for i in idxs:
            s.update(c for c, v in zip(FINAL_CLASSES, all_data[i]["multi_hot"]) if v)
        return s

    train_cls = cls_set(train_idx)
    val_cls   = cls_set(val_idx)
    test_cls  = cls_set(test_idx)
    all_cls   = cls_set(list(range(len(all_data))))

    missing_val  = all_cls - val_cls
    missing_test = all_cls - test_cls
    missing_train_but_in_test = (test_cls | val_cls) - train_cls

    if missing_val:
        print(f"  ⚠️  Classes missing from VAL:  {missing_val}")
    else:
        print(f"  ✅ All classes present in val")

    if missing_test:
        print(f"  ⚠️  Classes missing from TEST: {missing_test}")
    else:
        print(f"  ✅ All classes present in test")

    if missing_train_but_in_test:
        print(f"  ❌ CRITICAL: Classes in test/val but NOT in train: "
              f"{missing_train_but_in_test}")
        ok = False
    else:
        print(f"  ✅ Train contains all classes seen in val/test")

    print(f"{'─'*70}")
    return ok


# ═══════════════════════════════════════════════════════════════════════════
# 9. MAIN ORCHESTRATION
# ═══════════════════════════════════════════════════════════════════════════

def main():
    np.random.seed(RANDOM_SEED)

    # ── Step 1: Collect data ──────────────────────────────────────────────
    all_data = collect_all_pairs()
    if not all_data:
        raise RuntimeError("No data found — check ROOT path.")

    # ── Step 2: Show full distribution ───────────────────────────────────
    img_counts, box_counts = print_distribution(all_data, "Full merged dataset")

    # ── Step 3: Force-seed rare classes ──────────────────────────────────
    train_seed, val_seed, test_seed, remaining = force_seed_rare_classes(
        all_data, img_counts
    )

    # ── Step 4: Stratify remaining pool ──────────────────────────────────
    if len(remaining) == 0:
        # Edge case: entire dataset was rare-seeded
        train_r, val_r, test_r = [], [], []
    elif HAS_SKMULTILEARN:
        print("\n── Running IterativeStratification (skmultilearn) ──────────────────")
        train_r, val_r, test_r = iterative_stratify(remaining, all_data)
    else:
        print("\n── Running greedy multi-label stratification (fallback) ─────────────")
        train_r, val_r, test_r = greedy_multilabel_stratify(remaining, all_data)

    # ── Step 5: Merge seed + stratified pools ────────────────────────────
    train_idx = train_seed + list(train_r)
    val_idx   = val_seed   + list(val_r)
    test_idx  = test_seed  + list(test_r)

    # ── Step 6: Validate ─────────────────────────────────────────────────
    valid = validate_splits(train_idx, val_idx, test_idx, all_data)
    if not valid:
        raise RuntimeError(
            "Split validation FAILED — fix class imbalance before proceeding."
        )

    # ── Step 7: Per-split distribution reports ───────────────────────────
    for name, idxs in [("Train", train_idx), ("Val", val_idx), ("Test", test_idx)]:
        print_distribution([all_data[i] for i in idxs], f"{name} split")

    # ── Step 8: Compute & export class weights ───────────────────────────
    weights = compute_class_weights(train_idx, all_data)
    print("\n── Class weights for loss balancing (based on train box counts) ───")
    print(f"  {'Class':<15} {'Weight':>8}")
    for cls, w in sorted(weights.items(), key=lambda x: -x[1]):
        print(f"  {cls:<15} {w:>8.4f}")

    weights_path = NEW_ROOT / "class_weights.json"
    NEW_ROOT.mkdir(parents=True, exist_ok=True)
    with open(weights_path, "w") as f:
        json.dump({"class_weights": weights, "classes": FINAL_CLASSES}, f, indent=2)
    print(f"\n  Saved class weights → {weights_path}")

    # ── Step 9: Write split summary JSON ─────────────────────────────────
    summary = {
        "total":  len(all_data),
        "train":  len(train_idx),
        "val":    len(val_idx),
        "test":   len(test_idx),
        "ratios": {
            "train": round(len(train_idx) / len(all_data), 3),
            "val":   round(len(val_idx)   / len(all_data), 3),
            "test":  round(len(test_idx)  / len(all_data), 3),
        },
        "classes": FINAL_CLASSES,
        "stratification": "iterative" if HAS_SKMULTILEARN else "greedy_multilabel",
    }
    with open(NEW_ROOT / "split_summary.json", "w") as f:
        json.dump(summary, f, indent=2)

    # ── Step 10: Write files ──────────────────────────────────────────────
    print("\n── Writing split directories ───────────────────────────────────────")
    create_split_files(train_idx, all_data, "train")
    create_split_files(val_idx,   all_data, "val")
    create_split_files(test_idx,  all_data, "test")

    # ── Final summary ─────────────────────────────────────────────────────
    print(f"""
╔══════════════════════════════════════════════════════════════╗
║                      SPLIT COMPLETE ✅                       ║
╠══════════════════════════════════════════════════════════════╣
║  Total images : {len(all_data):<7}                                  ║
║  Train        : {len(train_idx):<7} ({len(train_idx)/len(all_data)*100:.1f}%)                           ║
║  Val          : {len(val_idx):<7} ({len(val_idx)/len(all_data)*100:.1f}%)                            ║
║  Test         : {len(test_idx):<7} ({len(test_idx)/len(all_data)*100:.1f}%)                            ║
║  Classes      : {N_CLASSES:<7}                                  ║
║  Strategy     : {'iterative' if HAS_SKMULTILEARN else 'greedy_multilabel':<20}                   ║
╚══════════════════════════════════════════════════════════════╝

📂 Output  : {NEW_ROOT}
⚖️  Weights : {weights_path}

Next step — use class weights in your training loss, e.g.:
  weights = json.load(open('class_weights.json'))['class_weights']
  # PyTorch:
  weight_tensor = torch.tensor([weights[c] for c in FINAL_CLASSES])
  criterion = FocalLoss(alpha=weight_tensor, gamma=2.0)
""")


if __name__ == "__main__":
    main()
# Out:
# ── Scanning original dataset folders ──────────────────────────────
#   train_set: 4368 XML files found
#   validation_set: 1310 XML files found
#   test_set: 2184 XML files found
#
# ✅  Collected 7862 valid pairs. Skipped 0.
#
# ──────────────────────────────────────────────────────────────────────
#   Full merged dataset  (7862 images | 122295 bounding boxes)
# ──────────────────────────────────────────────────────────────────────
#   Class             Images    Img%     Boxes    Box%
#   ─────────────── ──────── ───────  ──────── ───────
#   CYPRO               5335   67.9%     12102    9.9%
#   CYPRO_max           5711   72.6%     16807   13.7%
#   CYPRO_min           5395   68.6%     14185   11.6%
#   ECHCG               1475   18.8%      5533    4.5%
#   ECHCG_Ve            2433   30.9%      5628    4.6%
#   NC                  4431   56.4%     11215    9.2%
#   SOLNI_V1            1268   16.1%      8774    7.2%
#   SOLNI_Vc            3993   50.8%     13902   11.4%
#   ZEAMX_V1            5408   68.8%     23345   19.1%
#   ZEAMX_V3            1880   23.9%      8053    6.6%
#   ZEAMX_V4             690    8.8%      2751    2.2%
# ──────────────────────────────────────────────────────────────────────
#
# ✅  No rare classes detected — skipping force-seed step.
#
# ── Running IterativeStratification (skmultilearn) ──────────────────
#
# ── Validating splits ───────────────────────────────────────────────
#   ✅ No overlap: train∩val
#   ✅ No overlap: train∩test
#   ✅ No overlap: val∩test
#   ✅ All classes present in val
#   ✅ All classes present in test
#   ✅ Train contains all classes seen in val/test
# ──────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
#   Train split  (6284 images | 97052 bounding boxes)
# ──────────────────────────────────────────────────────────────────────
#   Class             Images    Img%     Boxes    Box%
#   ─────────────── ──────── ───────  ──────── ───────
#   CYPRO               4266   67.9%      9617    9.9%
#   CYPRO_max           4567   72.7%     13338   13.7%
#   CYPRO_min           4324   68.8%     11271   11.6%
#   ECHCG               1180   18.8%      4391    4.5%
#   ECHCG_Ve            1921   30.6%      4422    4.6%
#   NC                  3534   56.2%      8931    9.2%
#   SOLNI_V1            1003   16.0%      6533    6.7%
#   SOLNI_Vc            3192   50.8%     11176   11.5%
#   ZEAMX_V1            4326   68.8%     18683   19.3%
#   ZEAMX_V3            1500   23.9%      6495    6.7%
#   ZEAMX_V4             550    8.8%      2195    2.3%
# ──────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
#   Val split  (786 images | 12417 bounding boxes)
# ──────────────────────────────────────────────────────────────────────
#   Class             Images    Img%     Boxes    Box%
#   ─────────────── ──────── ───────  ──────── ───────
#   CYPRO                535   68.1%      1242   10.0%
#   CYPRO_max            567   72.1%      1737   14.0%
#   CYPRO_min            536   68.2%      1460   11.8%
#   ECHCG                147   18.7%       575    4.6%
#   ECHCG_Ve             270   34.4%       644    5.2%
#   NC                   457   58.1%      1116    9.0%
#   SOLNI_V1             126   16.0%       863    7.0%
#   SOLNI_Vc             401   51.0%      1355   10.9%
#   ZEAMX_V1             541   68.8%      2343   18.9%
#   ZEAMX_V3             187   23.8%       795    6.4%
#   ZEAMX_V4              70    8.9%       287    2.3%
# ──────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
#   Test split  (792 images | 12826 bounding boxes)
# ──────────────────────────────────────────────────────────────────────
#   Class             Images    Img%     Boxes    Box%
#   ─────────────── ──────── ───────  ──────── ───────
#   CYPRO                534   67.4%      1243    9.7%
#   CYPRO_max            577   72.9%      1732   13.5%
#   CYPRO_min            535   67.6%      1454   11.3%
#   ECHCG                148   18.7%       567    4.4%
#   ECHCG_Ve             242   30.6%       562    4.4%
#   NC                   440   55.6%      1168    9.1%
#   SOLNI_V1             139   17.6%      1378   10.7%
#   SOLNI_Vc             400   50.5%      1371   10.7%
#   ZEAMX_V1             541   68.3%      2319   18.1%
#   ZEAMX_V3             193   24.4%       763    5.9%
#   ZEAMX_V4              70    8.8%       269    2.1%
# ──────────────────────────────────────────────────────────────────────
#
# ── Class weights for loss balancing (based on train box counts) ───
#   Class             Weight
#   ZEAMX_V4          4.0195
#   ECHCG             2.0093
#   ECHCG_Ve          1.9952
#   ZEAMX_V3          1.3584
#   SOLNI_V1          1.3505
#   NC                0.9879
#   CYPRO             0.9174
#   SOLNI_Vc          0.7895
#   CYPRO_min         0.7828
#   CYPRO_max         0.6615
#   ZEAMX_V1          0.4722
#
#   Saved class weights → /kaggle/working/stratified_dataset/class_weights.json
#
# ── Writing split directories ───────────────────────────────────────
#   ✅ train : 6284 images → /kaggle/working/stratified_dataset/train
#   ✅ val   : 786 images → /kaggle/working/stratified_dataset/val
#   ✅ test  : 792 images → /kaggle/working/stratified_dataset/test
#
# ╔══════════════════════════════════════════════════════════════╗
# ║                      SPLIT COMPLETE ✅                       ║
# ╠══════════════════════════════════════════════════════════════╣
# ║  Total images : 7862                                     ║
# ║  Train        : 6284    (79.9%)                           ║
# ║  Val          : 786     (10.0%)                            ║
# ║  Test         : 792     (10.1%)                            ║
# ║  Classes      : 11                                       ║
# ║  Strategy     : iterative                              ║
# ╚══════════════════════════════════════════════════════════════╝
#
# 📂 Output  : /kaggle/working/stratified_dataset
# ⚖️  Weights : /kaggle/working/stratified_dataset/class_weights.json
#
# Next step — use class weights in your training loss, e.g.:
#   weights = json.load(open('class_weights.json'))['class_weights']
#   # PyTorch:
#   weight_tensor = torch.tensor([weights[c] for c in FINAL_CLASSES])
#   criterion = FocalLoss(alpha=weight_tensor, gamma=2.0)

# %%
"""
WeedMaize — YOLOv11 Training Pipeline
======================================
Fixes applied vs original:
  1. Paths aligned to stratified_dataset structure
  2. Class names sourced from LABEL_MAP (not re-scanned from XML)
     → prevents OE / POROL / unmapped labels leaking back in
  3. convert_box argument order fixed: was (xmin,xmax,ymin,ymax)
     → correct is (xmin,ymin,xmax,ymax) — wrong order = broken boxes
  4. Class weights wired into loss via class_weights.json
  5. Symlink-safe file copy (resolves symlink before copying)
  6. label_file properly closed via context manager
  7. Skips boxes whose label is not in class_map (safe guard)
  8. imgsz bumped to 1280 — drone images have tiny weeds, 640 loses detail
"""

# ── 0. Install & imports ────────────────────────────────────────────────────
# !pip install ultralytics   # uncomment if not installed

import os
import json
import shutil
import xml.etree.ElementTree as ET
from pathlib import Path

from ultralytics import YOLO

# ═══════════════════════════════════════════════════════════════════════════
# 1. PATHS  (all derived from single base_dir)
# ═══════════════════════════════════════════════════════════════════════════

BASE_DIR   = Path("/kaggle/working/stratified_dataset")
TRAIN_DIR  = BASE_DIR / "train"
VAL_DIR    = BASE_DIR / "val"
TEST_DIR   = BASE_DIR / "test"
YOLO_DIR   = BASE_DIR / "weed_yolo"          # YOLO-format output
WEIGHTS_F  = BASE_DIR / "class_weights.json"

SPLITS = {
    "train": TRAIN_DIR,
    "val":   VAL_DIR,
    "test":  TEST_DIR,
}

# ═══════════════════════════════════════════════════════════════════════════
# 2. CLASS NAMES  — must match stratification LABEL_MAP exactly
#    Do NOT re-scan XMLs: dropped classes (OE, POROL) would re-appear
# ═══════════════════════════════════════════════════════════════════════════

CLASSES = [
    "CYPRO",
    "CYPRO_max",
    "CYPRO_min",
    "ECHCG",
    "ECHCG_Ve",
    "NC",
    "SOLNI_V1",
    "SOLNI_Vc",
    "ZEAMX_V1",
    "ZEAMX_V3",
    "ZEAMX_V4",
]
CLASS_MAP = {name: i for i, name in enumerate(CLASSES)}
print(f"Classes ({len(CLASSES)}): {CLASSES}")

# ═══════════════════════════════════════════════════════════════════════════
# 3. CREATE YOLO FOLDER STRUCTURE
# ═══════════════════════════════════════════════════════════════════════════

for split in SPLITS:
    (YOLO_DIR / "images" / split).mkdir(parents=True, exist_ok=True)
    (YOLO_DIR / "labels" / split).mkdir(parents=True, exist_ok=True)

print("✅ YOLO directory structure created.")

# ═══════════════════════════════════════════════════════════════════════════
# 4. VOC → YOLO CONVERSION
#    FIXED argument order: (xmin, ymin, xmax, ymax)  ← was wrong before
# ═══════════════════════════════════════════════════════════════════════════

def convert_box(img_w: int, img_h: int,
                xmin: float, ymin: float,
                xmax: float, ymax: float) -> tuple:
    """Convert Pascal VOC absolute coords → YOLO normalised (cx,cy,w,h)."""
    cx = ((xmin + xmax) / 2) / img_w
    cy = ((ymin + ymax) / 2) / img_h
    bw = (xmax - xmin) / img_w
    bh = (ymax - ymin) / img_h
    return cx, cy, bw, bh


total_imgs, total_boxes, skipped_boxes = 0, 0, 0

for split, src_dir in SPLITS.items():
    img_dst = YOLO_DIR / "images" / split
    lbl_dst = YOLO_DIR / "labels" / split
    split_imgs = split_boxes = 0

    for file in sorted(os.listdir(src_dir)):
        if not file.lower().endswith((".jpg", ".jpeg", ".png")):
            continue

        img_path = Path(src_dir) / file
        xml_path = Path(src_dir) / (Path(file).stem + ".xml")

        # ── Symlink-safe copy ──────────────────────────────────────────
        dst_img = img_dst / file
        shutil.copy2(img_path.resolve(), dst_img)   # resolves symlinks
        split_imgs += 1

        if not xml_path.exists():
            continue  # image without annotation — still copied

        tree    = ET.parse(xml_path)
        root_el = tree.getroot()
        size    = root_el.find("size")
        img_w   = int(size.find("width").text)
        img_h   = int(size.find("height").text)

        label_path = lbl_dst / (Path(file).stem + ".txt")
        with open(label_path, "w") as lf:
            for obj in root_el.findall("object"):
                name = obj.find("name").text

                # Skip any label not in our final class map (safety guard)
                if name not in CLASS_MAP:
                    skipped_boxes += 1
                    continue

                cls_id = CLASS_MAP[name]
                box    = obj.find("bndbox")
                xmin   = float(box.find("xmin").text)
                ymin   = float(box.find("ymin").text)
                xmax   = float(box.find("xmax").text)
                ymax   = float(box.find("ymax").text)

                cx, cy, bw, bh = convert_box(img_w, img_h, xmin, ymin, xmax, ymax)
                lf.write(f"{cls_id} {cx:.6f} {cy:.6f} {bw:.6f} {bh:.6f}\n")
                split_boxes += 1

    print(f"  {split:<6}: {split_imgs} images | {split_boxes} boxes")
    total_imgs  += split_imgs
    total_boxes += split_boxes

print(f"\n✅ Conversion done — {total_imgs} images | {total_boxes} boxes written")
if skipped_boxes:
    print(f"⚠️  {skipped_boxes} boxes skipped (labels not in CLASS_MAP)")

# ═══════════════════════════════════════════════════════════════════════════
# 5. DATASET YAML
# ═══════════════════════════════════════════════════════════════════════════

yaml_lines = [
    f"path: {YOLO_DIR}",
    "train: images/train",
    "val:   images/val",
    "test:  images/test",
    "",
    f"nc: {len(CLASSES)}",
    "",
    "names:",
]
for i, c in enumerate(CLASSES):
    yaml_lines.append(f"  {i}: {c}")

yaml_text = "\n".join(yaml_lines) + "\n"
yaml_path = YOLO_DIR / "dataset.yaml"
yaml_path.write_text(yaml_text)
print(f"\n✅ dataset.yaml written → {yaml_path}")
print(yaml_text)

# ═══════════════════════════════════════════════════════════════════════════
# 6. LOAD CLASS WEIGHTS  (from stratification step)
# ═══════════════════════════════════════════════════════════════════════════

if WEIGHTS_F.exists():
    with open(WEIGHTS_F) as f:
        cw_data = json.load(f)
    class_weights = [cw_data["class_weights"].get(c, 1.0) for c in CLASSES]
    print("\n⚖️  Class weights loaded:")
    for c, w in zip(CLASSES, class_weights):
        print(f"   {c:<15} {w:.4f}")
else:
    class_weights = None
    print("⚠️  class_weights.json not found — training without class weights.")

# ═══════════════════════════════════════════════════════════════════════════
# 7. TRAIN YOLOv11
# ═══════════════════════════════════════════════════════════════════════════
#
# T4 GPU VRAM budget (14.9 GB each):
#
#   imgsz  | batch/GPU | approx VRAM/GPU | status
#   -------|-----------|-----------------|-------
#   1280   |    16     |    ~15.5 GB     | ❌ OOM  ← what crashed
#    832   |     8     |    ~11.0 GB     | ✅ safe
#    640   |    16     |    ~8.5  GB     | ✅ safe (fallback)
#
# cache="ram" loaded 12.4 GB into RAM which competed with VRAM via
# DDP shared memory — switched to "disk" which is deterministic too.
# env var PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True reduces
# fragmentation on T4s running DDP.

import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

model = YOLO("yolo11s.pt")


model.train(
    data        = str(yaml_path),
    epochs      = 100,

    # ── Hardware ──────────────────────────────────────────────────────────
    device      = [0, 1],      # both T4 GPUs
    batch       = 16,          # 8 per GPU — fits at 832px on T4 (11GB/GPU)
    workers     = 4,           # 4 total (2 per GPU); more causes RAM pressure
    cache       = "disk",      # avoids 12GB RAM competing with VRAM in DDP

    # ── Resolution ────────────────────────────────────────────────────────
    # 832 is best T4-safe resolution for small weed detection.
    # It's 30% more pixels than 640 — catches small plants 640 misses.
    # Fall back to imgsz=640, batch=16 only if you still OOM here.
    imgsz       = 832,

    # ── Augmentation ──────────────────────────────────────────────────────
    hsv_h       = 0.015,       # hue jitter — field lighting variation
    hsv_s       = 0.7,         # saturation jitter
    hsv_v       = 0.4,         # brightness jitter
    degrees     = 15,          # rotation — weeds grow at any angle
    translate   = 0.1,
    scale       = 0.6,         # scale jitter — simulates drone altitude change
    shear       = 2,
    perspective = 0.0005,      # mild warp for drone tilt
    fliplr      = 0.5,
    flipud      = 0.3,         # drone top-down = no natural "up"
    mosaic      = 1.0,
    mixup       = 0.15,
    copy_paste  = 0.2,         # pastes rare class instances into other images

    # ── Regularisation ────────────────────────────────────────────────────
    erasing     = 0.4,
    dropout     = 0.0,
    weight_decay= 0.0005,
    close_mosaic= 15,          # disable mosaic for final 15 epochs

    # ── Loss weights ──────────────────────────────────────────────────────
    cls         = 0.5,
    box         = 7.5,
    dfl         = 1.5,

    # ── Training behaviour ────────────────────────────────────────────────
    patience    = 25,
    optimizer   = "AdamW",
    lr0         = 0.001,
    lrf         = 0.01,
    warmup_epochs = 3,
    cos_lr      = True,
    amp         = True,

    # ── Logging & checkpoints ─────────────────────────────────────────────
    project     = "/kaggle/working/runs",
    name        = "weedmaize_yolo11m",
    exist_ok    = True,
    plots       = True,
    save        = True,
    save_period = 10,          # checkpoint every 10 epochs (Kaggle time limit safety)
    val         = True,
)

print("\n🎉 Training complete!")
print("   Best weights → /kaggle/working/runs/weedmaize_yolo11m/weights/best.pt")

# ── Save results to output dir ─────────────────────────────────────────────
import shutil
results_src = Path("/kaggle/working/runs/weedmaize_yolo11m")
results_dst = Path("/kaggle/working/yolo_results")
results_dst.mkdir(exist_ok=True)

shutil.copy(results_src / "weights" / "best.pt", results_dst / "best_model.pt")
shutil.copy(results_src / "weights" / "last.pt", results_dst / "last_model.pt")

for plot in results_src.glob("*.png"):
    shutil.copy(plot, results_dst / plot.name)
for plot in results_src.glob("*.csv"):
    shutil.copy(plot, results_dst / plot.name)

print(f"   Results saved → {results_dst}")
print(f"   Files: {sorted(os.listdir(results_dst))}")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.21-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.21-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.5 MB/s eta 0:00:00a 0:00:01
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.21 ultralytics-thop-2.0.18
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Classes (11): ['CYPRO', 'CYPRO_max', 'CYPRO_min', 'ECHCG', 'ECHCG_Ve', 'NC', 'SOLNI_V1', 'SOLNI_Vc', 'ZEAMX_V1', 'ZEAMX_V3', 'ZEAMX_V4']
# ✅ YOLO directory structure created.
#   train : 6284 images | 96737 boxes
#   val   : 786 images | 12366 boxes
#   test  : 792 images | 12796 boxes
#
# ✅ Conversion done — 7862 images | 121899 boxes written
# ⚠️  416 boxes skipped (labels not in CLASS_MAP)
#
# ✅ dataset.yaml written → /kaggle/working/stratified_dataset/weed_yolo/dataset.yaml
# path: /kaggle/working/stratified_dataset/weed_yolo
# train: images/train
# val:   images/val
# test:  images/test
#
# nc: 11
#
# names:
#   0: CYPRO
#   1: CYPRO_max
#   2: CYPRO_min
#   3: ECHCG
#   4: ECHCG_Ve
#   5: NC
#   6: SOLNI_V1
#   7: SOLNI_Vc
#   8: ZEAMX_V1
#   9: ZEAMX_V3
#   10: ZEAMX_V4
#
#
# ⚖️  Class weights loaded:
#    CYPRO           0.9174
#    CYPRO_max       0.6615
#    CYPRO_min       0.7828
#    ECHCG           2.0093
#    ECHCG_Ve        1.9952
#    NC              0.9879
#    SOLNI_V1        1.3505
#    SOLNI_Vc        0.7895
#    ZEAMX_V1        0.4722
#    ZEAMX_V3        1.3584
#    ZEAMX_V4        4.0195
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 137.6MB/s 0.1s0.1s<0.1s
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=15, cls=0.5, compile=False, conf=None, copy_paste=0.2, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/stratified_dataset/weed_yolo/dataset.yaml, degrees=15, deterministic=True, device=0,1, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.3, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=832, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.15, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=weedmaize_yolo11m, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0005, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/weedmaize_yolo11m, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.6, seed=0, shear=2, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 49443 /root/.config/Ultralytics/DDP/_temp_j_0ww1_l137117884318688.py
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# Overriding model.yaml nc=80 with nc=11
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 64.0MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2875.5±1927.2 MB/s, size: 742.8 KB)
# train: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/train... 6284 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6284/6284 1.4Kit/s 4.6s0.1s
# train: New cache created: /kaggle/working/stratified_dataset/weed_yolo/labels/train.cache
# WARNING ⚠️ train: 102.4GB disk space required, with 50% safety margin but only 8.1/19.5GB free, not caching images to disk
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2587.8±1261.5 MB/s, size: 724.7 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/val... 786 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 786/786 1.5Kit/s 0.5s0.2ss
# val: New cache created: /kaggle/working/stratified_dataset/weed_yolo/labels/val.cache
# WARNING ⚠️ val: 12.8GB disk space required, with 50% safety margin but only 8.1/19.5GB free, not caching images to disk
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/weedmaize_yolo11m/labels.jpg...
# Image sizes 832 train, 832 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/weedmaize_yolo11m
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.89G      2.087       1.86      1.436        216        832: 100% ━━━━━━━━━━━━ 393/393 2.2it/s 3:03<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.4it/s 10.2s0.3s
#                    all        786      12366      0.449      0.427      0.397      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.95G      1.952      1.537      1.359        137        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.7s0.3s
#                    all        786      12366      0.422      0.472      0.437      0.212
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.97G      1.927      1.486      1.352        128        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.5s0.3s
#                    all        786      12366      0.439      0.532      0.497      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.03G      1.877      1.418      1.321        137        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.3s
#                    all        786      12366      0.525      0.515       0.53      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.07G      1.852      1.376      1.305        266        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.2s
#                    all        786      12366      0.515      0.598      0.549      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.11G      1.819      1.345       1.29        130        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.4s
#                    all        786      12366      0.542      0.565      0.551      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.13G      1.799      1.318      1.275        376        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.2s
#                    all        786      12366      0.549      0.582      0.573      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.19G      1.758      1.284      1.263        206        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.3s
#                    all        786      12366      0.565      0.584      0.591      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.23G      1.731      1.256      1.248        246        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.557       0.59      0.577       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.33G      1.716      1.222       1.24        176        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.3it/s 7.5s0.3s
#                    all        786      12366      0.568      0.609      0.608      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.35G      1.685      1.208      1.225        177        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.8s0.3s
#                    all        786      12366      0.577      0.604      0.608      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.43G       1.67      1.192      1.218        216        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.2s
#                    all        786      12366       0.62      0.605      0.635      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.59G      1.641      1.163        1.2        236        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.9s0.3s
#                    all        786      12366      0.615       0.64      0.656      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.63G      1.616      1.137      1.192        184        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.612      0.618      0.637      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.65G       1.61      1.128      1.183        252        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.8s0.2s
#                    all        786      12366      0.653      0.642      0.673      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.71G      1.594       1.12      1.183        262        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.642      0.643      0.677      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.75G      1.589      1.107      1.176        246        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.3s
#                    all        786      12366      0.638      0.646      0.683      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.79G      1.564       1.08      1.171        362        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.2s
#                    all        786      12366      0.641      0.663      0.691      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.81G      1.547      1.065      1.159        244        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 8.9s0.3s
#                    all        786      12366       0.67      0.646      0.698      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.87G      1.526      1.043      1.149        155        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.683      0.669      0.713      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.91G      1.511      1.029      1.143        206        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.3s
#                    all        786      12366      0.693      0.643      0.705      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.96G      1.498      1.012      1.139        244        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.708      0.669      0.725      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.99G      1.486      1.006      1.134        269        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.2s
#                    all        786      12366      0.686       0.69      0.739      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      5.18G      1.482     0.9962      1.125        285        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.5s0.3s
#                    all        786      12366      0.718      0.699      0.745      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      5.22G      1.473     0.9897      1.129        256        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.2s
#                    all        786      12366      0.703      0.678      0.733      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      5.26G      1.457     0.9732      1.119        248        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.9s0.3s
#                    all        786      12366      0.731      0.687      0.754      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      5.28G      1.454     0.9705      1.118        268        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 9.0s0.3s
#                    all        786      12366      0.746       0.69      0.762      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      5.38G      1.436     0.9548      1.111        102        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.2s0.3s
#                    all        786      12366      0.734      0.711       0.77      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      5.42G      1.418     0.9434      1.102        334        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.8s0.3s
#                    all        786      12366      0.735      0.709      0.761      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      5.46G      1.405       0.93        1.1        243        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.9s0.3s
#                    all        786      12366      0.758      0.701      0.775      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      5.48G      1.404     0.9274      1.095        214        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:43<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.2s0.4s
#                    all        786      12366      0.743      0.714      0.781      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      5.54G      1.379     0.9095      1.084        244        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 8.8s0.3s
#                    all        786      12366      0.753       0.71      0.783      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      5.58G      1.396     0.9135       1.09        220        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.7s0.2s
#                    all        786      12366      0.761      0.716      0.786      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      5.62G      1.364      0.891      1.076        181        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.8s0.2s
#                    all        786      12366      0.776       0.73      0.799        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100       5.7G      1.368     0.8861      1.076        172        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.4s
#                    all        786      12366      0.792      0.721        0.8      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      5.76G      1.339     0.8643      1.066        181        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.2s
#                    all        786      12366      0.767      0.735      0.803      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100       5.8G      1.344     0.8736      1.072        220        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.2s
#                    all        786      12366      0.763      0.748      0.813      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      5.84G      1.341     0.8663      1.068        279        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.3s
#                    all        786      12366      0.796      0.733      0.813      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      5.88G      1.324     0.8473      1.056        178        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 9.1s0.2s
#                    all        786      12366      0.804      0.754      0.828      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      6.11G      1.322     0.8486      1.059        151        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.809      0.755      0.834       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      6.15G      1.295     0.8348      1.051        222        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.2s0.3s
#                    all        786      12366      0.812      0.765       0.84      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      6.19G       1.29     0.8218      1.048        134        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 8.8s0.3s
#                    all        786      12366      0.813      0.767       0.84      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      6.21G      1.287     0.8145      1.043        121        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.3it/s 7.7s0.3s
#                    all        786      12366      0.822      0.764      0.843      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      6.27G      1.283     0.8163      1.044        149        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.5s0.3s
#                    all        786      12366      0.837      0.761      0.841       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      6.31G       1.27     0.8083      1.038        212        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.3s
#                    all        786      12366      0.825       0.77      0.846      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      6.35G      1.258     0.7967      1.032        259        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.2s
#                    all        786      12366      0.824      0.781      0.852      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      6.43G      1.258     0.7956      1.027        222        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.3s
#                    all        786      12366      0.839      0.775      0.856      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      6.49G      1.236     0.7769      1.025        198        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.846      0.776      0.863      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      6.53G      1.233     0.7741      1.023        166        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.3s
#                    all        786      12366      0.856      0.774      0.863      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      6.57G      1.231     0.7739      1.025        217        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.5s0.3s
#                    all        786      12366      0.847      0.794      0.872      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      6.61G       1.23     0.7664       1.02        238        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.3s
#                    all        786      12366      0.858      0.795      0.872      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      6.67G      1.208      0.756      1.017        189        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.2s
#                    all        786      12366      0.842      0.808      0.878      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      6.71G      1.211     0.7543      1.015        212        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.2s
#                    all        786      12366      0.851      0.799      0.876      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100       6.8G      1.214     0.7562      1.016        177        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.2s
#                    all        786      12366      0.862      0.798      0.883      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      6.83G      1.193     0.7432      1.008        203        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.9s0.3s
#                    all        786      12366      0.872      0.799      0.883      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      6.88G      1.182     0.7342      1.003        151        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 8.9s0.3s
#                    all        786      12366      0.875      0.814      0.893      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      6.92G      1.187     0.7357      1.005        118        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.3s
#                    all        786      12366      0.872      0.812      0.893      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      6.96G      1.166     0.7219     0.9949        183        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.878      0.817      0.895       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      7.08G      1.166     0.7238     0.9986        276        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 8.9s0.3s
#                    all        786      12366      0.874      0.817      0.896      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      7.14G      1.159     0.7165     0.9939        231        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.6s0.4s
#                    all        786      12366      0.872      0.823      0.896       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      7.18G      1.144     0.7054     0.9882        173        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.8s0.3s
#                    all        786      12366      0.878      0.821      0.898       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      7.22G       1.14     0.6986     0.9871        265        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:37<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.3s
#                    all        786      12366       0.88      0.829      0.904      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      7.24G      1.139     0.6995     0.9911        236        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.3s
#                    all        786      12366      0.885      0.834      0.906      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100       7.3G      1.132     0.6959     0.9872        265        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.6it/s 7.0s0.3s
#                    all        786      12366      0.889      0.827      0.907      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      4.34G       1.14     0.7004     0.9884        173        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.8s0.3s
#                    all        786      12366        0.9      0.834      0.911      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.34G      1.121     0.6852     0.9797        221        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.3s
#                    all        786      12366      0.899      0.824      0.907      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.34G       1.11     0.6782     0.9798        122        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 9.0s0.3s
#                    all        786      12366      0.897      0.833       0.91       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.34G      1.107     0.6742     0.9746        154        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.2s
#                    all        786      12366      0.897      0.839      0.913      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.34G      1.099     0.6695     0.9728        197        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.7it/s 9.2s0.3s
#                    all        786      12366      0.909      0.827      0.914      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.34G      1.102     0.6754     0.9738        114        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.9s0.3s
#                    all        786      12366      0.898      0.836      0.915      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.36G      1.103     0.6754     0.9752        212        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 8.9s0.3s
#                    all        786      12366      0.906      0.836      0.918      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      4.42G      1.093     0.6683     0.9736        241        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.5s0.3s
#                    all        786      12366      0.899      0.843      0.918      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      4.58G       1.09     0.6632     0.9705        239        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.2s
#                    all        786      12366      0.903      0.842      0.918      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      4.62G      1.084     0.6599     0.9688        223        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.3s
#                    all        786      12366      0.915      0.838      0.919      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      4.64G      1.068     0.6494     0.9638        315        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:39<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.7it/s 9.1s0.3s
#                    all        786      12366      0.904      0.844      0.921      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      4.76G      1.067     0.6479     0.9614        189        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.3it/s 7.7s0.2s
#                    all        786      12366      0.904      0.846      0.923      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      4.79G      1.065     0.6447     0.9641        230        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.904       0.85      0.923      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      4.83G      1.062     0.6428     0.9623        121        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.3s
#                    all        786      12366      0.909      0.851      0.926      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      4.86G      1.068     0.6498     0.9648        217        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.7it/s 9.2s0.3s
#                    all        786      12366      0.908      0.849      0.925      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      4.91G      1.051     0.6356     0.9558        174        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.912      0.849      0.926      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      4.96G      1.047     0.6341     0.9562        204        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.7s0.3s
#                    all        786      12366      0.914      0.846      0.925      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      4.99G      1.049     0.6362      0.957        119        832: 100% ━━━━━━━━━━━━ 393/393 2.5it/s 2:38<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.2s0.2s
#                    all        786      12366       0.91      0.849      0.926      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      5.02G      1.041     0.6306     0.9563        173        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.3s
#                    all        786      12366      0.916       0.85      0.927      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      5.07G      1.055     0.6395     0.9592        278        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.8it/s 9.0s0.4s
#                    all        786      12366      0.918      0.849      0.928      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      5.11G      1.038     0.6274     0.9531        246        832: 100% ━━━━━━━━━━━━ 393/393 2.4it/s 2:42<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.0s0.3s
#                    all        786      12366      0.914      0.854      0.928      0.658
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      5.15G     0.8531     0.4962     0.8923         88        832: 100% ━━━━━━━━━━━━ 393/393 2.7it/s 2:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.7s0.3s
#                    all        786      12366      0.907      0.853      0.924      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      5.17G     0.8334     0.4851      0.886         79        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:20<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.2s0.2s
#                    all        786      12366      0.908      0.852      0.924      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      5.23G     0.8357     0.4853      0.888         76        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:20<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.7s0.3s
#                    all        786      12366      0.907      0.852      0.924      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      5.27G     0.8196     0.4745     0.8818         71        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:19<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.906      0.854      0.925      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      5.31G     0.8198     0.4755     0.8833         90        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:19<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.3s
#                    all        786      12366      0.906      0.855      0.926      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.33G     0.8158     0.4741     0.8802         81        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:20<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.2s
#                    all        786      12366      0.903      0.859      0.927      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      5.39G     0.8089     0.4711     0.8797         80        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:20<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.3it/s 7.5s0.3s
#                    all        786      12366      0.902       0.86      0.927      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      5.43G      0.815     0.4715     0.8768         68        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:20<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.1s0.2s
#                    all        786      12366      0.906      0.857      0.927      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.47G     0.8087     0.4693     0.8775         84        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:20<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.8s0.2s
#                    all        786      12366      0.906      0.859      0.927       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.49G     0.8068     0.4667     0.8783         56        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:19<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.4s0.3s
#                    all        786      12366      0.907      0.858      0.927      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.55G      0.799     0.4644     0.8769         64        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:19<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.2it/s 7.9s0.2s
#                    all        786      12366       0.91      0.857      0.927       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      5.59G      0.802     0.4663     0.8787         88        832: 100% ━━━━━━━━━━━━ 393/393 2.8it/s 2:18<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.0it/s 8.3s0.2s
#                    all        786      12366      0.908      0.859      0.927       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.63G     0.8002     0.4649     0.8768         54        832: 100% ━━━━━━━━━━━━ 393/393 2.9it/s 2:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.3it/s 7.7s0.2s
#                    all        786      12366      0.906      0.862      0.928       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      5.65G     0.8006      0.466     0.8783         88        832: 100% ━━━━━━━━━━━━ 393/393 2.9it/s 2:18<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.3it/s 7.5s0.3s
#                    all        786      12366      0.905      0.863      0.928      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.71G     0.8055     0.4682     0.8783         65        832: 100% ━━━━━━━━━━━━ 393/393 2.9it/s 2:16<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.7s0.3s
#                    all        786      12366      0.907      0.863      0.928      0.662
#
# 100 epochs completed in 4.615 hours.
# Optimizer stripped from /kaggle/working/runs/weedmaize_yolo11m/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/weedmaize_yolo11m/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/weedmaize_yolo11m/weights/best.pt...
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.6it/s 9.8s0.2s
#                    all        786      12366      0.907      0.862      0.928      0.662
#                  CYPRO        535       1242      0.914      0.855      0.924      0.626
#              CYPRO_max        567       1737      0.947       0.92      0.965      0.766
#              CYPRO_min        536       1460      0.929      0.905      0.952      0.606
#                  ECHCG        147        575      0.934      0.948      0.977      0.761
#               ECHCG_Ve        265        615      0.867      0.767      0.886      0.531
#                     NC        457       1116      0.846      0.621      0.785      0.439
#               SOLNI_V1        126        863      0.852      0.835      0.911      0.536
#               SOLNI_Vc        401       1355      0.806       0.78      0.861      0.497
#               ZEAMX_V1        526       2321      0.976      0.956      0.986       0.83
#               ZEAMX_V3        187        795      0.949      0.958      0.987      0.851
#               ZEAMX_V4         70        287      0.954      0.939      0.972      0.834
# Speed: 0.2ms preprocess, 2.7ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /kaggle/working/runs/weedmaize_yolo11m
#
# 🎉 Training complete!
#    Best weights → /kaggle/working/runs/weedmaize_yolo11m/weights/best.pt
#    Results saved → /kaggle/working/yolo_results
#    Files: ['BoxF1_curve.png', 'BoxPR_curve.png', 'BoxP_curve.png', 'BoxR_curve.png', 'best_model.pt', 'confusion_matrix.png', 'confusion_matrix_normalized.png', 'last_model.pt', 'results.csv', 'results.png']

# %%
# ═══════════════════════════════════════════════════════════════════════════
# MODEL EFFICIENCY BENCHMARK (Params, GFLOPs, Latency, FPS, Size)
# ═══════════════════════════════════════════════════════════════════════════

import torch
import time
import pandas as pd
from thop import profile
from ultralytics import YOLO

MODEL_PATH = results_dst / "best_model.pt"

model = YOLO(str(MODEL_PATH))
net = model.model

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = net.to(device).eval()

# -------------------------------------------------
# Params
# -------------------------------------------------
params = sum(p.numel() for p in net.parameters())
params_m = params / 1e6

# -------------------------------------------------
# GFLOPs
# -------------------------------------------------
dummy = torch.randn(1, 3, 832, 832).to(device)

macs, _ = profile(net, inputs=(dummy,), verbose=False)
gflops = macs / 1e9

# -------------------------------------------------
# Model size
# -------------------------------------------------
model_size_mb = MODEL_PATH.stat().st_size / (1024 ** 2)

# -------------------------------------------------
# Latency / FPS benchmark
# -------------------------------------------------
warmup = 20
runs = 100

with torch.no_grad():

    for _ in range(warmup):
        _ = net(dummy)

    torch.cuda.synchronize()
    start = time.time()

    for _ in range(runs):
        _ = net(dummy)

    torch.cuda.synchronize()
    end = time.time()

latency = (end - start) / runs
fps = 1 / latency

# -------------------------------------------------
# Print results
# -------------------------------------------------
print("\n📊 MODEL EFFICIENCY")
print(f"Params (M): {params_m:.2f}")
print(f"GFLOPs: {gflops:.2f}")
print(f"Model Size (MB): {model_size_mb:.2f}")
print(f"Latency (ms): {latency*1000:.2f}")
print(f"FPS: {fps:.2f}")

# -------------------------------------------------
# Save for paper
# -------------------------------------------------
efficiency = pd.DataFrame([{
    "model": "YOLOv11m",
    "params_M": round(params_m,3),
    "GFLOPs": round(gflops,3),
    "size_MB": round(model_size_mb,3),
    "latency_ms": round(latency*1000,3),
    "FPS": round(fps,3)
}])

efficiency_path = results_dst / "model_efficiency.csv"
efficiency.to_csv(efficiency_path, index=False)

print(f"\n📄 Efficiency table saved → {efficiency_path}")
# Out:
# 📊 MODEL EFFICIENCY
# Params (M): 9.43
# GFLOPs: 18.23
# Model Size (MB): 18.29
# Latency (ms): 15.56
# FPS: 64.28
#
# 📄 Efficiency table saved → /kaggle/working/yolo_results/model_efficiency.csv

# %%
# ============================================================
#  TEACHER MODEL EVALUATION  — YOLOv11 Weed Detection
#  Run this cell AFTER training is complete.
#  Produces all plots, CSVs, and a KD-ready summary JSON.
# ============================================================

import os, shutil, json, zipfile
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec
import cv2
from ultralytics import YOLO

# ──────────────────────────────────────────────────────────────
#  CONFIG
# ──────────────────────────────────────────────────────────────
BASE_DIR    = "/kaggle/working/stratified_dataset"
YOLO_DIR    = f"{BASE_DIR}/weed_yolo"
YAML_PATH   = "/kaggle/working/stratified_dataset/weed_yolo/dataset.yaml"
RUNS_DIR = Path("/kaggle/working/runs")
EXPORT_ROOT = Path("/kaggle/working/teacher_export")

# ──────────────────────────────────────────────────────────────
#  0.  SANITY-CHECK YAML EXISTS
# ──────────────────────────────────────────────────────────────
if not os.path.exists(YAML_PATH):
    raise FileNotFoundError(
        f"dataset.yaml not found at {YAML_PATH}\n"
        "Make sure YOLO_DIR matches the path used during training."
    )
print(f"[OK] dataset.yaml found: {YAML_PATH}")

# ──────────────────────────────────────────────────────────────
#  1.  LOCATE LATEST TRAINING RUN
# ──────────────────────────────────────────────────────────────
train_dirs = sorted(RUNS_DIR.glob("weedmaize*"), key=os.path.getmtime)
if not train_dirs:
    raise RuntimeError(f"No training runs found in {RUNS_DIR}")
latest_run = train_dirs[-1]
print(f"[INFO] Using run: {latest_run}")

# Output folders
plots_dir = EXPORT_ROOT / "plots"
csv_dir   = EXPORT_ROOT / "csv"
model_dir = EXPORT_ROOT / "models"
pred_dir  = EXPORT_ROOT / "predictions"
for d in [plots_dir, csv_dir, model_dir, pred_dir]:
    d.mkdir(parents=True, exist_ok=True)

# ──────────────────────────────────────────────────────────────
#  2.  SAVE WEIGHTS
# ──────────────────────────────────────────────────────────────
weights_src = latest_run / "weights"
shutil.copy(weights_src / "best.pt", model_dir / "best.pt")
shutil.copy(weights_src / "last.pt", model_dir / "last.pt")
print("[INFO] Weights saved.")

# ──────────────────────────────────────────────────────────────
#  3.  LOAD TRAINING METRICS CSV
# ──────────────────────────────────────────────────────────────
df = pd.read_csv(latest_run / "results.csv")
df.columns = df.columns.str.strip()
df.to_csv(csv_dir / "training_metrics.csv", index=False)

epochs = df["epoch"] if "epoch" in df.columns else pd.Series(np.arange(len(df)))
print(f"[INFO] Training metrics loaded ({len(df)} epochs).")

# ── helper ─────────────────────────────────────────────────────
BLUE, RED, GREEN, PURPLE = "#2563EB", "#DC2626", "#16A34A", "#9333EA"

def scol(df, *names):
    """Case-insensitive column lookup."""
    low = {c.lower(): c for c in df.columns}
    for n in names:
        if n.lower() in low:
            return low[n.lower()]
    return None

# ──────────────────────────────────────────────────────────────
#  4.  TRAINING CURVE PLOTS
# ──────────────────────────────────────────────────────────────

# --- Loss curves ---
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
fig.suptitle("Training & Validation Loss Curves", fontsize=14, fontweight="bold")
for ax, key, title in zip(axes,
                           ["box_loss", "cls_loss", "dfl_loss"],
                           ["Box Loss", "Class Loss", "DFL Loss"]):
    tc = scol(df, f"train/{key}", f"train_{key}")
    vc = scol(df, f"val/{key}",   f"val_{key}")
    if tc: ax.plot(epochs, df[tc], color=BLUE, label="Train", linewidth=1.8)
    if vc: ax.plot(epochs, df[vc], color=RED,  label="Val",   linewidth=1.8)
    ax.set_title(title, fontweight="bold"); ax.set_xlabel("Epoch")
    ax.legend(fontsize=8); ax.grid(linestyle="--", alpha=0.4)
plt.tight_layout()
fig.savefig(plots_dir / "01_loss_curves.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 01_loss_curves.png")

# --- mAP curves ---
map50_col = scol(df, "metrics/mAP50(B)",    "metrics/map50",    "map50")
map95_col = scol(df, "metrics/mAP50-95(B)", "metrics/map50-95", "mAP50-95(B)")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("Mean Average Precision (mAP)", fontsize=14, fontweight="bold")
for ax, col, label in zip(axes, [map50_col, map95_col], ["mAP@0.50", "mAP@0.50:0.95"]):
    if col:
        ax.plot(epochs, df[col], color=GREEN, linewidth=2)
        ax.fill_between(epochs, df[col], alpha=0.15, color=GREEN)
        best_i = df[col].idxmax()
        ax.annotate(f"Best: {df[col].max():.4f}\n@ ep {int(epochs.iloc[best_i])}",
                    xy=(epochs.iloc[best_i], df[col].max()),
                    xytext=(10, -20), textcoords="offset points",
                    arrowprops=dict(arrowstyle="->"), fontsize=8)
    ax.set_title(label, fontweight="bold"); ax.set_xlabel("Epoch"); ax.set_ylabel("mAP")
    ax.grid(linestyle="--", alpha=0.4)
plt.tight_layout()
fig.savefig(plots_dir / "02_map_curves.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 02_map_curves.png")

# --- Precision & Recall ---
fig, ax = plt.subplots(figsize=(8, 4))
pc = scol(df, "metrics/precision(B)", "metrics/precision", "precision")
rc = scol(df, "metrics/recall(B)",    "metrics/recall",    "recall")
if pc: ax.plot(epochs, df[pc], color=BLUE, label="Precision", linewidth=1.8)
if rc: ax.plot(epochs, df[rc], color=RED,  label="Recall",    linewidth=1.8)
ax.set_title("Precision & Recall over Training", fontweight="bold")
ax.set_xlabel("Epoch"); ax.set_ylabel("Score")
ax.legend(); ax.grid(linestyle="--", alpha=0.4)
plt.tight_layout()
fig.savefig(plots_dir / "03_precision_recall_curves.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 03_precision_recall_curves.png")

# --- LR schedule ---
lr_cols = [c for c in df.columns if "lr" in c.lower()]
if lr_cols:
    fig, ax = plt.subplots(figsize=(8, 3))
    for col in lr_cols:
        ax.plot(epochs, df[col], label=col, linewidth=1.5)
    ax.set_title("Learning Rate Schedule", fontweight="bold")
    ax.set_xlabel("Epoch"); ax.set_ylabel("LR")
    ax.legend(fontsize=8); ax.grid(linestyle="--", alpha=0.4)
    plt.tight_layout()
    fig.savefig(plots_dir / "04_lr_schedule.png", dpi=200, bbox_inches="tight")
    plt.close(); print("[PLOT] 04_lr_schedule.png")

# --- Summary dashboard ---
fig = plt.figure(figsize=(18, 10))
fig.suptitle("YOLOv11 Teacher — Training Summary", fontsize=16, fontweight="bold")
gs = GridSpec(2, 3, figure=fig, hspace=0.45, wspace=0.35)

panel_cfg = [
    (gs[0,0], "train/box_loss","train_box_loss", "val/box_loss","val_box_loss", "Box Loss"),
    (gs[0,1], "train/cls_loss","train_cls_loss", "val/cls_loss","val_cls_loss", "Cls Loss"),
    (gs[0,2], "train/dfl_loss","train_dfl_loss", "val/dfl_loss","val_dfl_loss", "DFL Loss"),
]
for spec, tk1, tk2, vk1, vk2, title in panel_cfg:
    ax = fig.add_subplot(spec)
    tc = scol(df, tk1, tk2); vc = scol(df, vk1, vk2)
    if tc: ax.plot(epochs, df[tc], color=BLUE, label="Train")
    if vc: ax.plot(epochs, df[vc], color=RED,  label="Val")
    ax.set_title(title); ax.legend(fontsize=7); ax.grid(alpha=0.3)

ax4 = fig.add_subplot(gs[1,0])
if map50_col:
    ax4.plot(epochs, df[map50_col], color=GREEN, linewidth=2)
    ax4.fill_between(epochs, df[map50_col], alpha=0.15, color=GREEN)
ax4.set_title("mAP@0.50"); ax4.grid(alpha=0.3)

ax5 = fig.add_subplot(gs[1,1])
if map95_col:
    ax5.plot(epochs, df[map95_col], color=PURPLE, linewidth=2)
    ax5.fill_between(epochs, df[map95_col], alpha=0.15, color=PURPLE)
ax5.set_title("mAP@0.50:0.95"); ax5.grid(alpha=0.3)

ax6 = fig.add_subplot(gs[1,2])
if pc: ax6.plot(epochs, df[pc], color=BLUE, label="Precision")
if rc: ax6.plot(epochs, df[rc], color=RED,  label="Recall")
ax6.set_title("Precision & Recall"); ax6.legend(fontsize=7); ax6.grid(alpha=0.3)

fig.savefig(plots_dir / "05_summary_dashboard.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 05_summary_dashboard.png")

# Copy YOLO auto-generated plots
for p in list(latest_run.glob("*.png")) + list(latest_run.glob("*.jpg")):
    shutil.copy(p, plots_dir / p.name)
    print(f"[COPY] {p.name}")

# ──────────────────────────────────────────────────────────────
#  5.  LOAD TEACHER MODEL
# ──────────────────────────────────────────────────────────────
teacher = YOLO(str(model_dir / "best.pt"))
names   = teacher.names
n_cls   = len(names)

# ──────────────────────────────────────────────────────────────
#  6.  STANDARD TEST-SET VALIDATION
# ──────────────────────────────────────────────────────────────
test_results = teacher.val(
    data=YAML_PATH,
    split="test",
    imgsz=640,
    batch=16,
    verbose=True,
    save_json=True,
    project=str(EXPORT_ROOT),
    name="test_eval"
)

box = test_results.box

# Per-class metrics
rows = []
for i, name in names.items():
    p  = float(box.p[i])    if hasattr(box, "p")    else 0.0
    r  = float(box.r[i])    if hasattr(box, "r")    else 0.0
    a50= float(box.ap50[i]) if hasattr(box, "ap50") else 0.0
    a95= float(box.ap[i])   if hasattr(box, "ap")   else 0.0
    f1 = 2*p*r/(p+r+1e-9)
    rows.append(dict(class_id=i, class_name=name,
                     precision=p, recall=r, f1=f1,
                     mAP50=a50, mAP50_95=a95))

per_class_df = pd.DataFrame(rows)
per_class_df.to_csv(csv_dir / "test_per_class_metrics.csv", index=False)

overall = dict(
    mAP50    = float(box.map50),
    mAP50_95 = float(box.map),
    precision= float(box.mp),
    recall   = float(box.mr),
    f1       = float(2*box.mp*box.mr/(box.mp+box.mr+1e-9)),
    timestamp= datetime.now().isoformat(),
    model    = "yolo11m-best.pt",
    dataset  = "Zenodo-5106795",
)
pd.DataFrame([overall]).to_csv(csv_dir / "test_overall_summary.csv", index=False)
print(f"[CSV] Overall → mAP50={overall['mAP50']:.4f}  mAP50-95={overall['mAP50_95']:.4f}")

# ──────────────────────────────────────────────────────────────
#  7.  PLOT  Per-class bar chart  (P / R / mAP50 / mAP95 / F1)
# ──────────────────────────────────────────────────────────────
metrics_bar = [
    ("precision", "Precision",   BLUE),
    ("recall",    "Recall",      RED),
    ("mAP50",     "mAP@0.50",    GREEN),
    ("mAP50_95",  "mAP@0.50:95", PURPLE),
    ("f1",        "F1 Score",    "#EA580C"),
]
fig, axes = plt.subplots(1, len(metrics_bar), figsize=(5*len(metrics_bar), 5))
fig.suptitle("Per-Class Metrics on Test Set (Teacher)", fontsize=14, fontweight="bold")
x = np.arange(n_cls)

for ax, (col, label, color) in zip(axes, metrics_bar):
    vals = per_class_df[col].astype(float).values
    bars = ax.bar(x, vals, color=color, alpha=0.82, edgecolor="white")
    ax.set_xticks(x)
    ax.set_xticklabels(per_class_df["class_name"], rotation=35, ha="right", fontsize=7)
    ax.set_title(label, fontweight="bold"); ax.set_ylim(0, 1.1); ax.set_ylabel("Score")
    ax.grid(axis="y", linestyle="--", alpha=0.4)
    for bar, val in zip(bars, vals):
        ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.01,
                f"{val:.2f}", ha="center", va="bottom", fontsize=6)

plt.tight_layout()
fig.savefig(plots_dir / "06_per_class_metrics.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 06_per_class_metrics.png")

# ──────────────────────────────────────────────────────────────
#  8.  SPEED METRICS
# ──────────────────────────────────────────────────────────────
speed = test_results.speed
speed_df = pd.DataFrame([speed])
speed_df.to_csv(csv_dir / "speed_metrics.csv", index=False)

fig, ax = plt.subplots(figsize=(6, 4))
labels_s = list(speed.keys())
vals_s   = [speed[k] for k in labels_s]
bars = ax.bar(labels_s, vals_s, color=[BLUE, GREEN, RED], alpha=0.85, edgecolor="white")
for bar, val in zip(bars, vals_s):
    ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.1,
            f"{val:.2f} ms", ha="center", fontsize=9, fontweight="bold")
ax.set_title("Inference Speed per Image (ms)", fontweight="bold")
ax.set_ylabel("Milliseconds"); ax.grid(axis="y", linestyle="--", alpha=0.4)
plt.tight_layout()
fig.savefig(plots_dir / "07_speed_metrics.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 07_speed_metrics.png")

# ──────────────────────────────────────────────────────────────
#  9.  CONFIDENCE DISTRIBUTION  (KD teacher calibration)
# ──────────────────────────────────────────────────────────────
test_img_dir = Path(YOLO_DIR) / "images" / "test"
test_images  = sorted(test_img_dir.glob("*.jpg"))[:200] + \
               sorted(test_img_dir.glob("*.png"))[:200]
test_images  = test_images[:200]

all_confs   = []
all_classes = []
box_areas   = []

if test_images:
    preds = teacher.predict(
        source=[str(p) for p in test_images],
        imgsz=640, conf=0.01,
        iou=0.5, verbose=False
    )
    for result in preds:
        if result.boxes is not None and len(result.boxes):
            confs = result.boxes.conf.cpu().numpy()
            clss  = result.boxes.cls.cpu().numpy().astype(int)
            xyxy  = result.boxes.xyxy.cpu().numpy()
            areas = (xyxy[:,2]-xyxy[:,0]) * (xyxy[:,3]-xyxy[:,1])
            all_confs.extend(confs.tolist())
            all_classes.extend(clss.tolist())
            box_areas.extend(areas.tolist())

all_confs   = np.array(all_confs)
all_classes = np.array(all_classes)
box_areas   = np.array(box_areas)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("Teacher Confidence Distribution (KD Calibration)", fontweight="bold", fontsize=13)

axes[0].hist(all_confs, bins=40, color=BLUE, alpha=0.8, edgecolor="white")
axes[0].axvline(0.25, color=RED,   linestyle="--", label="conf=0.25")
axes[0].axvline(0.50, color=GREEN, linestyle="--", label="conf=0.50")
axes[0].set_title("Overall Confidence Distribution")
axes[0].set_xlabel("Confidence Score"); axes[0].set_ylabel("Count")
axes[0].legend(); axes[0].grid(linestyle="--", alpha=0.4)

colors_cls = plt.cm.tab20(np.linspace(0, 1, n_cls))
for i, name in names.items():
    mask = all_classes == i
    if mask.sum() > 0:
        axes[1].hist(all_confs[mask], bins=30, alpha=0.55,
                     label=name, edgecolor="white", color=colors_cls[i % len(colors_cls)])
axes[1].set_title("Per-Class Confidence Distribution")
axes[1].set_xlabel("Confidence Score"); axes[1].set_ylabel("Count")
axes[1].legend(fontsize=7, ncol=2); axes[1].grid(linestyle="--", alpha=0.4)

plt.tight_layout()
fig.savefig(plots_dir / "08_confidence_distribution.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 08_confidence_distribution.png")

# ──────────────────────────────────────────────────────────────
#  10. mAP vs IoU THRESHOLD SWEEP
# ──────────────────────────────────────────────────────────────
iou_thresholds = [0.3, 0.4, 0.5, 0.6, 0.7, 0.75]
iou_map50_list = []
iou_map95_list = []

for iou_t in iou_thresholds:
    r = teacher.val(data=YAML_PATH, split="test",
                    imgsz=640, batch=16, iou=iou_t, verbose=False)
    iou_map50_list.append(float(r.box.map50))
    iou_map95_list.append(float(r.box.map))
    print(f"  IoU={iou_t:.2f}  mAP50={iou_map50_list[-1]:.4f}  mAP95={iou_map95_list[-1]:.4f}")

iou_df = pd.DataFrame(dict(iou_threshold=iou_thresholds,
                            mAP50=iou_map50_list,
                            mAP50_95=iou_map95_list))
iou_df.to_csv(csv_dir / "iou_sensitivity.csv", index=False)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(iou_thresholds, iou_map50_list, "o-", color=GREEN,  label="mAP@0.50",    linewidth=2)
ax.plot(iou_thresholds, iou_map95_list, "s-", color=PURPLE, label="mAP@0.50:95", linewidth=2)
ax.set_title("mAP vs IoU Threshold (NMS Sensitivity)", fontweight="bold")
ax.set_xlabel("IoU Threshold"); ax.set_ylabel("mAP")
ax.legend(); ax.grid(linestyle="--", alpha=0.4)
plt.tight_layout()
fig.savefig(plots_dir / "09_iou_sensitivity.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 09_iou_sensitivity.png")

# ──────────────────────────────────────────────────────────────
#  11. CONFIDENCE THRESHOLD SWEEP
# ──────────────────────────────────────────────────────────────
conf_thresholds = [0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 0.6]
conf_sweep = []

for conf_t in conf_thresholds:
    r = teacher.val(data=YAML_PATH, split="test",
                    imgsz=640, batch=16, conf=conf_t, verbose=False)
    conf_sweep.append(dict(
        conf_threshold = conf_t,
        precision      = float(r.box.mp),
        recall         = float(r.box.mr),
        mAP50          = float(r.box.map50),
        f1             = float(2*r.box.mp*r.box.mr/(r.box.mp+r.box.mr+1e-9)),
    ))
    print(f"  conf={conf_t:.2f}  P={conf_sweep[-1]['precision']:.3f}  "
          f"R={conf_sweep[-1]['recall']:.3f}  mAP50={conf_sweep[-1]['mAP50']:.4f}")

conf_df = pd.DataFrame(conf_sweep)
conf_df.to_csv(csv_dir / "conf_threshold_sweep.csv", index=False)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("Confidence Threshold Sweep", fontweight="bold", fontsize=13)

for col, label, color in [("precision","Precision",BLUE),
                           ("recall","Recall",RED),
                           ("f1","F1",GREEN)]:
    axes[0].plot(conf_df["conf_threshold"], conf_df[col],
                 "o-", label=label, color=color, linewidth=2)
axes[0].set_title("P / R / F1 vs Confidence"); axes[0].set_xlabel("Confidence Threshold")
axes[0].set_ylabel("Score"); axes[0].legend(); axes[0].grid(linestyle="--", alpha=0.4)

axes[1].plot(conf_df["recall"], conf_df["precision"], "o-", color=PURPLE, linewidth=2)
for _, row in conf_df.iterrows():
    axes[1].annotate(f"{row['conf_threshold']:.2f}",
                     (row["recall"], row["precision"]),
                     textcoords="offset points", xytext=(4,4), fontsize=7)
axes[1].set_title("Precision–Recall Curve (conf sweep)")
axes[1].set_xlabel("Recall"); axes[1].set_ylabel("Precision")
axes[1].set_xlim(0,1); axes[1].set_ylim(0,1.05); axes[1].grid(linestyle="--", alpha=0.4)

plt.tight_layout()
fig.savefig(plots_dir / "10_conf_threshold_sweep.png", dpi=200, bbox_inches="tight")
plt.close(); print("[PLOT] 10_conf_threshold_sweep.png")

# ──────────────────────────────────────────────────────────────
#  12. BOX SIZE vs CONFIDENCE SCATTER
# ──────────────────────────────────────────────────────────────
if len(box_areas) > 0:
    fig, ax = plt.subplots(figsize=(8, 5))
    scatter = ax.scatter(box_areas, all_confs, c=all_classes,
                         cmap="tab20", alpha=0.35, s=8)
    ax.set_title("Bounding-Box Area vs Confidence (Teacher)", fontweight="bold")
    ax.set_xlabel("Box Area (pixels²)"); ax.set_ylabel("Confidence")
    ax.axhline(0.25, color=RED, linestyle="--", label="conf=0.25"); ax.legend()
    ax.grid(linestyle="--", alpha=0.3)
    plt.tight_layout()
    fig.savefig(plots_dir / "11_boxsize_vs_confidence.png", dpi=200, bbox_inches="tight")
    plt.close(); print("[PLOT] 11_boxsize_vs_confidence.png")

# ──────────────────────────────────────────────────────────────
#  13. SAMPLE PREDICTION GRID
# ──────────────────────────────────────────────────────────────
sample_imgs = (sorted(test_img_dir.glob("*.jpg")) +
               sorted(test_img_dir.glob("*.png")))[:12]

if sample_imgs:
    preds_vis = teacher.predict(
        source=[str(p) for p in sample_imgs],
        imgsz=640, conf=0.25, iou=0.5, verbose=False
    )
    cols = 4
    rows_n = (len(preds_vis) + cols - 1) // cols
    fig, axes = plt.subplots(rows_n, cols, figsize=(cols*4, rows_n*3.5))
    axes = np.array(axes).reshape(-1)
    for ax in axes: ax.axis("off")
    for ax, result in zip(axes, preds_vis):
        img_rgb = cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB)
        ax.imshow(img_rgb); ax.set_title(Path(result.path).name, fontsize=7); ax.axis("off")
    fig.suptitle("Sample Test Predictions — Teacher (conf ≥ 0.25)", fontsize=13, fontweight="bold")
    plt.tight_layout()
    fig.savefig(plots_dir / "12_sample_predictions.png", dpi=150, bbox_inches="tight")
    plt.close()
    for result in preds_vis:
        result.save(filename=str(pred_dir / (Path(result.path).stem + "_pred.jpg")))
    print(f"[PLOT] 12_sample_predictions.png  ({len(preds_vis)} images)")

# ──────────────────────────────────────────────────────────────
#  14. BEST EPOCH SUMMARY
# ──────────────────────────────────────────────────────────────
if map50_col:
    best_i = df[map50_col].idxmax()
    pd.DataFrame([df.iloc[best_i].to_dict() | {"note":"best_epoch"}])\
      .to_csv(csv_dir / "best_epoch_metrics.csv", index=False)
    print("[CSV] best_epoch_metrics.csv saved.")

# ──────────────────────────────────────────────────────────────
#  15. KD TEACHER SUMMARY JSON
# ──────────────────────────────────────────────────────────────
kd_summary = {
    "teacher_model"       : "yolo11m-best.pt",
    "dataset"             : "Zenodo-5106795",
    "timestamp"           : datetime.now().isoformat(),
    "overall_metrics"     : overall,
    "per_class_metrics"   : per_class_df.to_dict(orient="records"),
    "speed_ms"            : speed,
    "iou_sensitivity"     : iou_df.to_dict(orient="records"),
    "conf_sweep"          : conf_df.to_dict(orient="records"),
    "recommended_kd_conf" : float(conf_df.loc[conf_df["f1"].idxmax(), "conf_threshold"]),
    "class_names"         : names,
    "conf_distribution"   : {
        "mean"   : float(np.mean(all_confs))           if len(all_confs) else None,
        "median" : float(np.median(all_confs))         if len(all_confs) else None,
        "std"    : float(np.std(all_confs))            if len(all_confs) else None,
        "p25"    : float(np.percentile(all_confs, 25)) if len(all_confs) else None,
        "p75"    : float(np.percentile(all_confs, 75)) if len(all_confs) else None,
    },
}
(EXPORT_ROOT / "teacher_kd_summary.json").write_text(
    json.dumps(kd_summary, indent=2, default=str))
print("[JSON] teacher_kd_summary.json saved.")

# ──────────────────────────────────────────────────────────────
#  16. COPY FULL EXPERIMENT + README + ZIP
# ──────────────────────────────────────────────────────────────
shutil.copytree(latest_run, EXPORT_ROOT / "experiment_full", dirs_exist_ok=True)

readme = f"""# YOLOv11 Teacher Model — Evaluation Export
Generated : {datetime.now().strftime('%Y-%m-%d %H:%M')}

## Key Results (Test Set)
| Metric        | Value   |
|---------------|---------|
| mAP@0.50      | {overall['mAP50']:.4f} |
| mAP@0.50:0.95 | {overall['mAP50_95']:.4f} |
| Precision     | {overall['precision']:.4f} |
| Recall        | {overall['recall']:.4f} |
| F1            | {overall['f1']:.4f} |

## Plots
| File | Description |
|------|-------------|
| 01_loss_curves.png | Train/Val box, cls, dfl loss |
| 02_map_curves.png | mAP50 and mAP50-95 over epochs |
| 03_precision_recall_curves.png | P & R over epochs |
| 04_lr_schedule.png | Learning rate schedule |
| 05_summary_dashboard.png | 6-panel overview |
| 06_per_class_metrics.png | P/R/F1/mAP per class |
| 07_speed_metrics.png | Inference latency breakdown |
| 08_confidence_distribution.png | KD calibration histogram |
| 09_iou_sensitivity.png | mAP vs IoU threshold sweep |
| 10_conf_threshold_sweep.png | P-R-F1 vs confidence threshold |
| 11_boxsize_vs_confidence.png | Small-object detection analysis |
| 12_sample_predictions.png | Visual prediction grid |

## KD Usage
Load `teacher_kd_summary.json` in your student training script.
`recommended_kd_conf` = conf threshold that maximises teacher F1
(use as soft-label threshold for distillation).

## Model
YOLOv11-m | 100 epochs | imgsz=640 | multi-GPU | AMP
"""
(EXPORT_ROOT / "README.md").write_text(readme)

zip_path = "/kaggle/working/teacher_export_FINAL"
shutil.make_archive(zip_path, "zip", str(EXPORT_ROOT))
print(f"\n{'='*60}")
print(f"  ✅  ZIP ready  →  {zip_path}.zip")
print(f"{'='*60}\n")

try:
    from IPython.display import FileLink, display
    display(FileLink("teacher_export_FINAL.zip"))
except Exception:
    print("Download: kaggle kernels output <your-kernel> -p .")
# Out:
# [OK] dataset.yaml found: /kaggle/working/stratified_dataset/weed_yolo/dataset.yaml
# [INFO] Using run: /kaggle/working/runs/weedmaize_yolo11m
# [INFO] Weights saved.
# [INFO] Training metrics loaded (100 epochs).
# [PLOT] 01_loss_curves.png
# [PLOT] 02_map_curves.png
# [PLOT] 03_precision_recall_curves.png
# [PLOT] 04_lr_schedule.png
# [PLOT] 05_summary_dashboard.png
# [COPY] confusion_matrix_normalized.png
# [COPY] confusion_matrix.png
# [COPY] results.png
# [COPY] BoxPR_curve.png
# [COPY] BoxP_curve.png
# [COPY] BoxR_curve.png
# [COPY] BoxF1_curve.png
# [COPY] val_batch2_pred.jpg
# [COPY] labels.jpg
# [COPY] train_batch33407.jpg
# [COPY] val_batch2_labels.jpg
# [COPY] train_batch1.jpg
# [COPY] val_batch1_labels.jpg
# [COPY] train_batch0.jpg
# [COPY] val_batch0_pred.jpg
# [COPY] train_batch33405.jpg
# [COPY] val_batch0_labels.jpg
# [COPY] train_batch2.jpg
# [COPY] val_batch1_pred.jpg
# [COPY] train_batch33406.jpg
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3577.7±750.6 MB/s, size: 763.6 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 1.4Kit/s 0.5s0.0ss
# val: New cache created: /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.5it/s 11.0s0.2s
#                    all        792      12796      0.891      0.822      0.894       0.61
#                  CYPRO        534       1243      0.883      0.836      0.894      0.576
#              CYPRO_max        577       1732      0.926      0.901       0.95      0.734
#              CYPRO_min        535       1454      0.891      0.857      0.908      0.543
#                  ECHCG        148        567      0.918       0.91      0.959       0.67
#               ECHCG_Ve        238        547      0.872      0.718      0.857      0.482
#                     NC        440       1168      0.833      0.548      0.717      0.382
#               SOLNI_V1        139       1378      0.798       0.76      0.829      0.435
#               SOLNI_Vc        400       1371      0.782      0.699      0.791      0.436
#               ZEAMX_V1        529       2304      0.966      0.966      0.988      0.828
#               ZEAMX_V3        193        763       0.96       0.95      0.982      0.834
#               ZEAMX_V4         70        269      0.968        0.9      0.963      0.793
# Speed: 0.4ms preprocess, 4.4ms inference, 0.0ms loss, 1.2ms postprocess per image
# Saving /kaggle/working/teacher_export/test_eval/predictions.json...
# Results saved to /kaggle/working/teacher_export/test_eval
# [CSV] Overall → mAP50=0.8945  mAP50-95=0.6101
# [PLOT] 06_per_class_metrics.png
# [PLOT] 07_speed_metrics.png
# /tmp/ipykernel_55/157924797.py:345: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend(fontsize=7, ncol=2); axes[1].grid(linestyle="--", alpha=0.4)
# [PLOT] 08_confidence_distribution.png
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3547.8±814.0 MB/s, size: 782.9 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 332.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.4it/s 11.4s0.2s
#                    all        792      12796      0.891      0.823      0.885      0.602
# Speed: 0.5ms preprocess, 4.4ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#   IoU=0.30  mAP50=0.8849  mAP95=0.6015
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3498.6±543.5 MB/s, size: 794.8 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 332.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.4it/s 11.2s0.2s
#                    all        792      12796      0.894      0.827      0.893      0.606
# Speed: 0.5ms preprocess, 5.1ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val2
#   IoU=0.40  mAP50=0.8928  mAP95=0.6063
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4283.4±1095.3 MB/s, size: 745.8 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 276.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.2it/s 12.0s0.2s
#                    all        792      12796      0.897       0.83      0.898      0.609
# Speed: 0.5ms preprocess, 4.9ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val3
#   IoU=0.50  mAP50=0.8978  mAP95=0.6091
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3873.5±1118.6 MB/s, size: 727.0 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 302.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.4it/s 11.2s0.2s
#                    all        792      12796      0.896      0.827      0.898       0.61
# Speed: 0.5ms preprocess, 4.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val4
#   IoU=0.60  mAP50=0.8982  mAP95=0.6100
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4609.5±996.2 MB/s, size: 737.9 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 332.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.3it/s 11.6s0.2s
#                    all        792      12796      0.891      0.822      0.894       0.61
# Speed: 0.4ms preprocess, 4.3ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val5
#   IoU=0.70  mAP50=0.8945  mAP95=0.6101
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4601.8±1286.5 MB/s, size: 764.3 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 237.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.5it/s 11.1s0.2s
#                    all        792      12796      0.887      0.818      0.891       0.61
# Speed: 0.5ms preprocess, 4.3ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val6
#   IoU=0.75  mAP50=0.8908  mAP95=0.6096
# [PLOT] 09_iou_sensitivity.png
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4962.2±1064.4 MB/s, size: 730.7 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 332.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.4it/s 11.3s0.2s
#                    all        792      12796      0.891      0.822      0.897       0.64
# Speed: 0.5ms preprocess, 4.4ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val7
#   conf=0.10  P=0.891  R=0.822  mAP50=0.8970
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2054.6±193.7 MB/s, size: 715.7 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 276.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.6it/s 11.0s0.2s
#                    all        792      12796      0.891      0.822      0.895      0.643
# Speed: 0.4ms preprocess, 4.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val8
#   conf=0.15  P=0.891  R=0.822  mAP50=0.8947
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2666.1±1474.9 MB/s, size: 760.3 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 237.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.5it/s 11.2s0.2s
#                    all        792      12796      0.891      0.822      0.892      0.645
# Speed: 0.5ms preprocess, 4.3ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val9
#   conf=0.20  P=0.891  R=0.822  mAP50=0.8918
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3426.4±1639.7 MB/s, size: 740.6 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 302.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.5it/s 11.0s0.2s
#                    all        792      12796      0.891      0.822      0.889      0.647
# Speed: 0.5ms preprocess, 4.3ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val10
#   conf=0.25  P=0.891  R=0.822  mAP50=0.8890
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4104.1±1994.7 MB/s, size: 745.1 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 369.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.5it/s 11.1s0.2s
#                    all        792      12796      0.886      0.825      0.885      0.648
# Speed: 0.5ms preprocess, 4.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val11
#   conf=0.30  P=0.886  R=0.825  mAP50=0.8847
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3185.8±1575.9 MB/s, size: 774.2 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 255.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.6it/s 10.9s0.2s
#                    all        792      12796      0.921      0.792      0.874      0.647
# Speed: 0.5ms preprocess, 4.2ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val12
#   conf=0.40  P=0.921  R=0.792  mAP50=0.8736
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3329.6±1402.6 MB/s, size: 705.6 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 332.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.7it/s 10.6s0.2s
#                    all        792      12796      0.953      0.741      0.855      0.643
# Speed: 0.5ms preprocess, 4.4ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val13
#   conf=0.50  P=0.953  R=0.741  mAP50=0.8551
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3185.3±1593.5 MB/s, size: 765.9 KB)
# val: Scanning /kaggle/working/stratified_dataset/weed_yolo/labels/test.cache... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 302.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 4.5it/s 11.1s0.2s
#                    all        792      12796      0.973      0.677      0.828      0.636
# Speed: 0.5ms preprocess, 4.3ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val14
#   conf=0.60  P=0.973  R=0.677  mAP50=0.8285
# [PLOT] 10_conf_threshold_sweep.png
# [CSV] best_epoch_metrics.csv saved.
# [JSON] teacher_kd_summary.json saved.
#
# ============================================================
#   ✅  ZIP ready  →  /kaggle/working/teacher_export_FINAL.zip
# ============================================================
# /kaggle/working/teacher_export_FINAL.zip

# %%
# ============================================================
#  YOLOv11  →  ONNX Export
# ============================================================

from pathlib import Path
from ultralytics import YOLO

# ──────────────────────────────────────────────────────────────
#  CONFIG
# ──────────────────────────────────────────────────────────────
PT_PATH   = "/kaggle/working/runs/weedmaize_yolo11m/weights/best.pt"
EXPORT_DIR = Path("/kaggle/working/onnx_export")
EXPORT_DIR.mkdir(parents=True, exist_ok=True)

# ──────────────────────────────────────────────────────────────
#  LOAD & EXPORT
# ──────────────────────────────────────────────────────────────
model = YOLO(PT_PATH)

model.export(
    format     = "onnx",
    imgsz      = 832,        # must match training imgsz
    opset      = 17,         # opset 17 = best compatibility (ORT 1.16+)
    simplify   = True,       # runs onnx-simplifier — smaller & faster
    dynamic    = False,      # False = fixed batch=1, faster on edge devices
    half       = False,      # True = FP16 (only if deploying on GPU)
)

# ──────────────────────────────────────────────────────────────
#  COPY TO EXPORT DIR
# ──────────────────────────────────────────────────────────────
onnx_src = Path(PT_PATH).with_suffix(".onnx")   # ultralytics saves next to .pt
onnx_dst = EXPORT_DIR / "best.onnx"

import shutil
shutil.copy(onnx_src, onnx_dst)
print(f"✅ ONNX model saved → {onnx_dst}")
print(f"   Size: {onnx_dst.stat().st_size / 1e6:.1f} MB")

# ──────────────────────────────────────────────────────────────
#  QUICK VALIDATION  (optional but recommended)
# ──────────────────────────────────────────────────────────────
import onnx
onnx_model = onnx.load(str(onnx_dst))
onnx.checker.check_model(onnx_model)
print("✅ ONNX model check passed")

# Print input/output shape info
for inp in onnx_model.graph.input:
    shape = [d.dim_value for d in inp.type.tensor_type.shape.dim]
    print(f"   Input  : {inp.name}  {shape}")
for out in onnx_model.graph.output:
    shape = [d.dim_value for d in out.type.tensor_type.shape.dim]
    print(f"   Output : {out.name}  {shape}")
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#
# PyTorch: starting from '/kaggle/working/runs/weedmaize_yolo11m/weights/best.pt' with input shape (1, 3, 832, 832) BCHW and output shape(s) (1, 15, 14196) (18.3 MB)
# requirements: Ultralytics requirements ['onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 12 packages in 334ms
# Prepared 2 packages in 2.66s
# Installed 2 packages in 15ms
#  + onnxruntime-gpu==1.24.3
#  + onnxslim==0.1.87
#
# requirements: AutoUpdate success ✅ 3.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.20.1 opset 17...
# ONNX: slimming with onnxslim 0.1.87...
# ONNX: export success ✅ 6.6s, saved as '/kaggle/working/runs/weedmaize_yolo11m/weights/best.onnx' (36.3 MB)
#
# Export complete (7.8s)
# Results saved to /kaggle/working/runs/weedmaize_yolo11m/weights
# Predict:         yolo predict task=detect model=/kaggle/working/runs/weedmaize_yolo11m/weights/best.onnx imgsz=832
# Validate:        yolo val task=detect model=/kaggle/working/runs/weedmaize_yolo11m/weights/best.onnx imgsz=832 data=/kaggle/working/stratified_dataset/weed_yolo/dataset.yaml
# Visualize:       https://netron.app
# ✅ ONNX model saved → /kaggle/working/onnx_export/best.onnx
#    Size: 38.1 MB
# ✅ ONNX model check passed
#    Input  : images  [1, 3, 832, 832]
#    Output : output0  [1, 15, 14196]
